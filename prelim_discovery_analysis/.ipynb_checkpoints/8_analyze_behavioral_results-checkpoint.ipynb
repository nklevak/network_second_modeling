# %%
# this loads  the behavioral data for the discovery sample and looks at their performance across sessions

# %%
import os
import numpy as np
import pandas as pd
import nibabel as nib
import nilearn
import json
import datetime
import pickle
import seaborn as sns
import gc
import psutil
import math
import scipy.stats as stats
from matplotlib.patches import Patch
from nilearn import plotting
from nilearn.glm.first_level import FirstLevelModel
from nilearn.glm.second_level import SecondLevelModel
from nilearn.glm import threshold_stats_img
from nilearn.image import concat_imgs, mean_img, index_img
from nilearn.reporting import make_glm_report
from nilearn import masking, image
from nilearn import datasets
from scipy.stats import pearsonr
import matplotlib.pyplot as plt
from collections import defaultdict

# %%
# subjects in the discovery sample
SUBJECTS = ['s03', 's10', 's19', 's29', 's43']
BASE_DIR = '/oak/stanford/groups/russpold/data/network_grant/behavioral_data/qc/discovery/'
filename_ending = '_desc-qc.csv'

# %%
subj_files = {}

# %%
for subj in SUBJECTS:
    subj_files[subj] = {'file_loc':[],'loaded':[]}
    subj_files[subj]['file_loc'] = f'{BASE_DIR}{subj}/{subj}{filename_ending}'

    try:
        df = pd.read_csv(subj_files[subj]['file_loc'])
        subj_files[subj]['loaded'] = df
    except FileNotFoundError:
        print(f"File not found: {subj_files[subj]['file_loc']}")
    except Exception as e:
        print(f"An error occurred while loading {subj_files[subj]['file_loc']}: {e}")

# %%
def split_info(df):
    df[['subject', 'session', 'task']] = df['info'].str.split('_', expand=True)
    return df

for subj in SUBJECTS:
    print(f"for subj {subj}")
    # print(subj_files[subj]['loaded'])

    curr_df = subj_files[subj]['loaded']
    curr_df = split_info(curr_df).drop(columns = "info")
    curr_df['task_count'] = curr_df.groupby(['subject', 'task']).cumcount() + 1
    
    subj_files[subj]['loaded'] = curr_df

    print(subj_files[subj]['loaded'].head())
# Out:
# for subj s03
#      go_acc  nogo_acc       go_rt  nogo_fail_rt   SDD_acc  DNN_acc  DDD_acc  \
# 0  0.977778       1.0  467.840909           NaN       NaN      NaN      NaN
# 1       NaN       NaN         NaN           NaN  0.913043     0.96     0.96
# 2       NaN       NaN         NaN           NaN       NaN      NaN      NaN
# 3       NaN       NaN         NaN           NaN       NaN      NaN      NaN
# 4       NaN       NaN         NaN           NaN       NaN      NaN      NaN
#
#    DDS_acc  SSS_acc  DSD_acc  ...  incongruent_stop_acc  incongruent_go_acc  \
# 0      NaN      NaN      NaN  ...                   NaN                 NaN
# 1      1.0      0.9      1.0  ...                   NaN                 NaN
# 2      NaN      NaN      NaN  ...                   NaN                 NaN
# 3      NaN      NaN      NaN  ...                   NaN                 NaN
# 4      NaN      NaN      NaN  ...                   NaN                 NaN
#
#    congruent_go_succ_rt  congruent_stop_fail_rt  incongruent_go_succ_rt  \
# 0                   NaN                     NaN                     NaN
# 1                   NaN                     NaN                     NaN
# 2                   NaN                     NaN                     NaN
# 3                   NaN                     NaN                     NaN
# 4                   NaN                     NaN                     NaN
#
#    incongruent_stop_fail_rt  subject  session                task  task_count
# 0                       NaN      s03   ses-01              goNogo         1.0
# 1                       NaN      s03   ses-01       shapeMatching         1.0
# 2                       NaN      s03   ses-01           spatialTS         1.0
# 3                       NaN      s03   ses-02              cuedTS         1.0
# 4                       NaN      s03   ses-02  directedForgetting         1.0
#
# [5 rows x 89 columns]
# for subj s10
#    cstay_acc  cswitch_tstay_acc  cswitch_tswitch_acc  cstay_tstay_acc  \
# 0   0.984375           0.960784             0.844156              NaN
# 1        NaN                NaN                  NaN              NaN
# 2        NaN                NaN                  NaN              NaN
# 3        NaN                NaN                  NaN              NaN
# 4        NaN                NaN                  NaN              NaN
#
#    cstay_tswitch_acc    cstay_rt  cswitch_tstay_rt  cswitch_tswitch_rt  \
# 0                NaN  637.238095        670.938776          682.369231
# 1                NaN         NaN               NaN                 NaN
# 2                NaN         NaN               NaN                 NaN
# 3                NaN         NaN               NaN                 NaN
# 4                NaN         NaN               NaN                 NaN
#
#    cstay_tstay_rt  cstay_tswitch_rt  ...  incongruent_stop_acc  \
# 0             NaN               NaN  ...                   NaN
# 1             NaN               NaN  ...                   NaN
# 2             NaN               NaN  ...                   NaN
# 3             NaN               NaN  ...                   NaN
# 4             NaN               NaN  ...                   NaN
#
#    incongruent_go_acc  congruent_go_succ_rt  congruent_stop_fail_rt  \
# 0                 NaN                   NaN                     NaN
# 1                 NaN                   NaN                     NaN
# 2                 NaN                   NaN                     NaN
# 3                 NaN                   NaN                     NaN
# 4                 NaN                   NaN                     NaN
#
#    incongruent_go_succ_rt  incongruent_stop_fail_rt  subject  session  \
# 0                     NaN                       NaN      s10   ses-01
# 1                     NaN                       NaN      s10   ses-01
# 2                     NaN                       NaN      s10   ses-01
# 3                     NaN                       NaN      s10   ses-01
# 4                     NaN                       NaN      s10   ses-02
#
#                  task  task_count
# 0              cuedTS         1.0
# 1             flanker         1.0
# 2              goNogo         1.0
# 3               nBack         1.0
# 4  directedForgetting         1.0
#
# [5 rows x 89 columns]
# for subj s19
#    cstay_acc  cswitch_tstay_acc  cswitch_tswitch_acc  cstay_tstay_acc  \
# 0   0.914894              0.875             0.845361              NaN
# 1        NaN                NaN                  NaN              NaN
# 2        NaN                NaN                  NaN              NaN
# 3        NaN                NaN                  NaN              NaN
# 4        NaN                NaN                  NaN              NaN
#
#    cstay_tswitch_acc    cstay_rt  cswitch_tstay_rt  cswitch_tswitch_rt  \
# 0                NaN  585.372093        645.166667          676.353659
# 1                NaN         NaN               NaN                 NaN
# 2                NaN         NaN               NaN                 NaN
# 3                NaN         NaN               NaN                 NaN
# 4                NaN         NaN               NaN                 NaN
#
#    cstay_tstay_rt  cstay_tswitch_rt  ...  pos_incongruent_rt  \
# 0             NaN               NaN  ...                 NaN
# 1             NaN               NaN  ...                 NaN
# 2             NaN               NaN  ...                 NaN
# 3             NaN               NaN  ...                 NaN
# 4             NaN               NaN  ...                 NaN
#
#    neg_incongruent_rt  con_incongruent_rt  pos_congruent_rt  neg_congruent_rt  \
# 0                 NaN                 NaN               NaN               NaN
# 1                 NaN                 NaN               NaN               NaN
# 2                 NaN                 NaN               NaN               NaN
# 3                 NaN                 NaN               NaN               NaN
# 4                 NaN                 NaN               NaN               NaN
#
#    con_congruent_rt  subject  session                task  task_count
# 0               NaN      s19   ses-01              cuedTS         1.0
# 1               NaN      s19   ses-01  directedForgetting         1.0
# 2               NaN      s19   ses-01             flanker         1.0
# 3               NaN      s19   ses-01          stopSignal         1.0
# 4               NaN      s19   ses-02               nBack         1.0
#
# [5 rows x 89 columns]
# for subj s29
#    con_acc   pos_acc   neg_acc   con_rt      pos_rt      neg_rt   SDD_acc  \
# 0      1.0  0.883721  0.809524  628.125  679.157895  676.941176       NaN
# 1      NaN       NaN       NaN      NaN         NaN         NaN  0.935484
# 2      NaN       NaN       NaN      NaN         NaN         NaN       NaN
# 3      NaN       NaN       NaN      NaN         NaN         NaN       NaN
# 4      NaN       NaN       NaN      NaN         NaN         NaN       NaN
#
#    DNN_acc  DDD_acc  DDS_acc  ...  incongruent_stop_acc  incongruent_go_acc  \
# 0      NaN      NaN      NaN  ...                   NaN                 NaN
# 1      1.0      1.0      1.0  ...                   NaN                 NaN
# 2      NaN      NaN      NaN  ...                   NaN                 NaN
# 3      NaN      NaN      NaN  ...                   NaN                 NaN
# 4      NaN      NaN      NaN  ...                   NaN                 NaN
#
#    congruent_go_succ_rt  congruent_stop_fail_rt  incongruent_go_succ_rt  \
# 0                   NaN                     NaN                     NaN
# 1                   NaN                     NaN                     NaN
# 2                   NaN                     NaN                     NaN
# 3                   NaN                     NaN                     NaN
# 4                   NaN                     NaN                     NaN
#
#    incongruent_stop_fail_rt  subject  session                task  task_count
# 0                       NaN      s29   ses-01  directedForgetting         1.0
# 1                       NaN      s29   ses-01       shapeMatching         1.0
# 2                       NaN      s29   ses-01           spatialTS         1.0
# 3                       NaN      s29   ses-01          stopSignal         1.0
# 4                       NaN      s29   ses-02              cuedTS         1.0
#
# [5 rows x 89 columns]
# for subj s43
#    cstay_acc  cswitch_tstay_acc  cswitch_tswitch_acc  cstay_tstay_acc  \
# 0   0.862745           0.741935             0.746835              NaN
# 1        NaN                NaN                  NaN              NaN
# 2        NaN                NaN                  NaN              NaN
# 3        NaN                NaN                  NaN              NaN
# 4        NaN                NaN                  NaN              NaN
#
#    cstay_tswitch_acc  cstay_rt  cswitch_tstay_rt  cswitch_tswitch_rt  \
# 0                NaN     846.0        914.717391         1019.525424
# 1                NaN       NaN               NaN                 NaN
# 2                NaN       NaN               NaN                 NaN
# 3                NaN       NaN               NaN                 NaN
# 4                NaN       NaN               NaN                 NaN
#
#    cstay_tstay_rt  cstay_tswitch_rt  ...  pos_incongruent_rt  \
# 0             NaN               NaN  ...                 NaN
# 1             NaN               NaN  ...                 NaN
# 2             NaN               NaN  ...                 NaN
# 3             NaN               NaN  ...                 NaN
# 4             NaN               NaN  ...                 NaN
#
#    neg_incongruent_rt  con_incongruent_rt  pos_congruent_rt  neg_congruent_rt  \
# 0                 NaN                 NaN               NaN               NaN
# 1                 NaN                 NaN               NaN               NaN
# 2                 NaN                 NaN               NaN               NaN
# 3                 NaN                 NaN               NaN               NaN
# 4                 NaN                 NaN               NaN               NaN
#
#    con_congruent_rt  subject  session                task  task_count
# 0               NaN      s43   ses-01              cuedTS         1.0
# 1               NaN      s43   ses-01               nBack         1.0
# 2               NaN      s43   ses-01       shapeMatching         1.0
# 3               NaN      s43   ses-01          stopSignal         1.0
# 4               NaN      s43   ses-02  directedForgetting         1.0
#
# [5 rows x 89 columns]

# %%
dataframes = []

for subj in SUBJECTS:
    if subj_files[subj]['loaded'] is not None:
        dataframes.append(subj_files[subj]['loaded'])

# Concatenate all dfs
combined_df = pd.concat(dataframes, ignore_index=True)

# %%
task_list = [task for task in combined_df["task"].unique() if task is not None]
print(task_list)
# Out:
# ['goNogo', 'shapeMatching', 'spatialTS', 'cuedTS', 'directedForgetting', 'flanker', 'nBack', 'stopSignal', 'directedForgettingWFlanker', 'stopSignalWDirectedForgetting', 'stopSignalWFlanker']

# %%
dfs_task_list = {}
task_acc_list = {}
for task in task_list:
    curr_df = combined_df[combined_df["task"] == task].dropna(axis=1, how='any')
    # Store the filtered DataFrame in the dictionary
    dfs_task_list[task] = curr_df

    # print(dfs_task_list[task])

    # save the name of the acc cols:
    acc_columns = [col for col in curr_df.columns if col.endswith('_acc')]
    task_acc_list[task] = acc_columns
    print(task_acc_list[task])

print(dfs_task_list)
# Out:
# ['go_acc', 'nogo_acc']
# ['SDD_acc', 'DNN_acc', 'DDD_acc', 'DDS_acc', 'SSS_acc', 'DSD_acc', 'SNN_acc']
# ['cstay_acc', 'cswitch_tstay_acc', 'cswitch_tswitch_acc']
# ['cstay_acc', 'cswitch_tstay_acc', 'cswitch_tswitch_acc']
# ['con_acc', 'pos_acc', 'neg_acc']
# ['congruent_acc', 'incongruent_acc']
# ['mismatch_1back_acc', 'match_1back_acc', 'mismatch_2back_acc', 'match_2back_acc']
# ['stop_succ_acc', 'go_succ_acc']
# ['pos_incongruent_acc', 'neg_incongruent_acc', 'con_incongruent_acc', 'pos_congruent_acc', 'neg_congruent_acc', 'con_congruent_acc']
# ['pos_stop_acc', 'pos_go_acc', 'neg_stop_acc', 'neg_go_acc', 'con_stop_acc', 'con_go_acc']
# ['congruent_stop_acc', 'congruent_go_acc', 'incongruent_stop_acc', 'incongruent_go_acc']
# {'goNogo':        go_acc  nogo_acc       go_rt subject session    task  task_count
# 0    0.977778  1.000000  467.840909     s03  ses-01  goNogo         1.0
# 8    1.000000  0.982456  370.697436     s03  ses-03  goNogo         2.0
# 16   0.961722  1.000000  418.666667     s03  ses-05  goNogo         3.0
# 24   0.985437  0.869565  418.556650     s03  ses-07  goNogo         4.0
# 32   0.929907  0.921053  450.884422     s03  ses-09  goNogo         5.0
# 49   1.000000  0.947368  354.446154     s10  ses-01  goNogo         1.0
# 57   0.995215  0.906977  329.769231     s10  ses-03  goNogo         2.0
# 65   1.000000  0.972222  382.316667     s10  ses-05  goNogo         3.0
# 73   1.000000  0.934783  354.859223     s10  ses-07  goNogo         4.0
# 81   1.000000  0.934783  329.349515     s10  ses-09  goNogo         5.0
# 105  0.985981  0.947368  369.473934     s19  ses-04  goNogo         1.0
# 113  0.967290  1.000000  373.579710     s19  ses-06  goNogo         2.0
# 121  0.995146  0.934783  380.292683     s19  ses-08  goNogo         3.0
# 129  0.977778  0.972222  362.250000     s19  ses-10  goNogo         4.0
# 152  0.995327  0.736842  370.859155     s29  ses-04  goNogo         1.0
# 160  1.000000  0.877193  359.841026     s29  ses-06  goNogo         2.0
# 168  1.000000  0.804348  342.237864     s29  ses-08  goNogo         3.0
# 175  1.000000  0.902778  340.050000     s29  ses-10  goNogo         4.0
# 197  1.000000  0.978261  407.334951     s43  ses-04  goNogo         1.0
# 205  1.000000  1.000000  437.317949     s43  ses-06  goNogo         2.0
# 213  1.000000  0.973684  405.046729     s43  ses-08  goNogo         3.0
# 221  1.000000  0.976744  289.688995     s43  ses-10  goNogo         4.0, 'shapeMatching':       SDD_acc   DNN_acc   DDD_acc   DDS_acc   SSS_acc   DSD_acc   SNN_acc  \
# 1    0.913043  0.960000  0.960000  1.000000  0.900000  1.000000  0.928571
# 10   0.969697  1.000000  1.000000  0.950000  1.000000  0.956522  0.961538
# 18   1.000000  0.975000  1.000000  1.000000  1.000000  1.000000  0.971429
# 26   1.000000  0.965517  1.000000  0.925926  0.958333  0.960000  1.000000
# 34   0.925926  0.958333  0.920000  0.950000  0.923077  1.000000  0.875000
# 52   0.833333  0.920000  1.000000  0.969697  1.000000  1.000000  1.000000
# 60   0.935484  0.958333  1.000000  1.000000  1.000000  1.000000  1.000000
# 68   0.869565  0.937500  1.000000  1.000000  1.000000  1.000000  1.000000
# 76   0.935484  0.960000  1.000000  0.958333  0.950000  1.000000  0.964286
# 84   1.000000  0.937500  1.000000  1.000000  1.000000  1.000000  0.906977
# 99   0.772727  1.000000  0.913043  1.000000  0.750000  0.916667  0.892857
# 107  0.888889  0.954545  0.965517  0.964286  1.000000  0.965517  1.000000
# 115  0.846154  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 123  0.724138  0.920000  1.000000  0.900000  1.000000  0.894737  1.000000
# 131  0.823529  1.000000  1.000000  1.000000  1.000000  1.000000  0.976744
# 140  0.935484  1.000000  1.000000  1.000000  0.937500  1.000000  0.954545
# 147  0.960000  1.000000  1.000000  1.000000  0.866667  1.000000  1.000000
# 155  0.791667  0.826087  1.000000  0.952381  0.800000  0.880000  0.800000
# 163  0.842105  1.000000  0.916667  0.947368  0.888889  1.000000  0.939394
# 171  0.961538  1.000000  1.000000  1.000000  1.000000  0.961538  0.925926
# 186  0.965517  1.000000  1.000000  1.000000  1.000000  1.000000  0.956522
# 193  0.954545  1.000000  0.965517  1.000000  0.958333  1.000000  1.000000
# 201  1.000000  0.904762  1.000000  1.000000  0.961538  0.947368  1.000000
# 209  0.857143  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 217  0.928571  1.000000  1.000000  1.000000  0.962963  1.000000  1.000000
#
#          SDD_rt      DNN_rt      DDD_rt      DDS_rt      SSS_rt      DSD_rt  \
# 1    773.476190  686.750000  729.333333  793.538462  715.611111  721.000000
# 10   714.406250  605.772727  653.500000  691.631579  632.409091  688.136364
# 18   753.263158  629.846154  664.800000  751.181818  732.590909  667.666667
# 26   804.086957  655.857143  711.041667  749.840000  728.043478  684.541667
# 34   685.480000  634.347826  642.782609  711.263158  670.166667  667.727273
# 52   561.000000  581.652174  591.041667  628.093750  524.296296  584.888889
# 60   562.827586  575.434783  578.272727  589.473684  527.043478  589.600000
# 68   601.400000  571.200000  578.307692  610.960000  527.652174  550.884615
# 76   586.896552  546.250000  573.157895  594.782609  534.684211  596.809524
# 84   539.000000  527.666667  540.333333  558.631579  521.148148  564.625000
# 99   791.823529  618.900000  700.714286  752.296296  772.055556  687.272727
# 107  722.625000  598.904762  665.571429  688.037037  680.687500  714.571429
# 115  726.136364  594.277778  697.444444  742.233333  667.681818  655.185185
# 123  770.190476  581.782609  684.680000  821.777778  649.727273  694.764706
# 131  649.571429  548.156250  568.312500  703.588235  553.000000  607.500000
# 140  717.068966  666.217391  736.043478  718.900000  696.900000  661.764706
# 147  784.000000  694.869565  668.346154  713.826087  741.615385  695.346154
# 155  648.526316  588.789474  596.533333  640.150000  620.062500  622.409091
# 163  728.562500  602.690476  600.727273  665.944444  664.062500  600.360000
# 171  629.240000  575.952381  575.080000  602.904762  614.454545  586.840000
# 186  801.500000  652.909091  704.960000  740.100000  721.600000  708.583333
# 193  729.857143  614.259259  625.928571  643.565217  700.521739  693.294118
# 201  726.290323  669.526316  675.176471  757.037037  681.600000  675.222222
# 209  677.000000  592.260870  619.826087  651.538462  642.000000  619.714286
# 217  675.346154  597.681818  634.950000  633.250000  605.153846  626.285714
#
#          SNN_rt subject session           task  task_count
# 1    701.884615     s03  ses-01  shapeMatching         1.0
# 10   656.840000     s03  ses-03  shapeMatching         2.0
# 18   643.588235     s03  ses-05  shapeMatching         3.0
# 26   756.187500     s03  ses-07  shapeMatching         4.0
# 34   667.428571     s03  ses-09  shapeMatching         5.0
# 52   486.000000     s10  ses-02  shapeMatching         1.0
# 60   507.083333     s10  ses-04  shapeMatching         2.0
# 68   496.724138     s10  ses-06  shapeMatching         3.0
# 76   518.518519     s10  ses-08  shapeMatching         4.0
# 84   488.743590     s10  ses-10  shapeMatching         5.0
# 99   722.840000     s19  ses-02  shapeMatching         1.0
# 107  667.192308     s19  ses-04  shapeMatching         2.0
# 115  604.703704     s19  ses-06  shapeMatching         3.0
# 123  632.928571     s19  ses-08  shapeMatching         4.0
# 131  555.976190     s19  ses-10  shapeMatching         5.0
# 140  660.809524     s29  ses-01  shapeMatching         1.0
# 147  716.033333     s29  ses-03  shapeMatching         2.0
# 155  648.000000     s29  ses-05  shapeMatching         3.0
# 163  610.870968     s29  ses-07  shapeMatching         4.0
# 171  585.520000     s29  ses-09  shapeMatching         5.0
# 186  677.818182     s43  ses-01  shapeMatching         1.0
# 193  679.884615     s43  ses-03  shapeMatching         2.0
# 201  670.222222     s43  ses-05  shapeMatching         3.0
# 209  600.103448     s43  ses-07  shapeMatching         4.0
# 217  578.923077     s43  ses-09  shapeMatching         5.0  , 'spatialTS':      cstay_acc  cswitch_tstay_acc  cswitch_tswitch_acc    cstay_rt  \
# 2     1.000000           1.000000             0.968750  813.145833
# 11    0.933333           0.986842             0.957746  732.952381
# 19    1.000000           0.957447             0.896907  789.770833
# 27    0.967213           0.938462             0.878788  755.677966
# 35    0.952381           0.957143             0.950000  725.125000
# 53    0.967213           0.969231             0.848485  559.322034
# 61    0.880952           0.971429             0.862500  588.540541
# 69    0.979167           0.957447             0.876289  583.297872
# 77    0.977778           0.986842             0.887324  543.500000
# 85    0.958333           0.854167             0.895833  562.021739
# 100   0.933333           0.960526             0.873239  631.785714
# 108   0.983607           0.938462             0.939394  716.316667
# 116   0.979167           0.978723             0.927835  679.936170
# 124   0.958333           0.958333             0.875000  772.521739
# 132   0.976190           0.928571             0.900000  623.560976
# 141   0.916667           0.957447             0.835052  763.454545
# 148   0.934426           0.969231             0.863636  680.105263
# 156   0.904762           0.942857             0.850000  620.473684
# 164   0.916667           0.979167             0.802083  597.727273
# 172   0.866667           0.921053             0.845070  569.769231
# 190   0.955556           0.973684             0.845070  678.674419
# 198   0.937500           0.936170             0.876289  713.600000
# 206   0.934426           0.953846             0.863636  686.070175
# 214   0.937500           0.958333             0.854167  634.288889
# 222   0.976190           0.971429             0.887500  638.121951
#
#      cswitch_tstay_rt  cswitch_tswitch_rt subject session       task  \
# 2          935.812500          980.752688     s03  ses-01  spatialTS
# 11         709.000000          870.441176     s03  ses-03  spatialTS
# 19         758.244444          879.252874     s03  ses-05  spatialTS
# 27         752.459016          938.431034     s03  ses-07  spatialTS
# 35         758.089552          870.868421     s03  ses-09  spatialTS
# 53         550.476190          628.410714     s10  ses-02  spatialTS
# 61         553.750000          638.159420     s10  ses-04  spatialTS
# 69         599.377778          648.258824     s10  ses-06  spatialTS
# 77         570.533333          656.349206     s10  ses-08  spatialTS
# 85         550.902439          632.348837     s10  ses-10  spatialTS
# 100        666.479452          808.306452     s19  ses-02  spatialTS
# 108        748.704918          880.629032     s19  ses-04  spatialTS
# 116        746.782609          812.088889     s19  ses-06  spatialTS
# 124        765.152174          823.869048     s19  ses-08  spatialTS
# 132        639.907692          755.277778     s19  ses-10  spatialTS
# 141        764.155556          894.395062     s29  ses-01  spatialTS
# 148        680.920635          842.771930     s29  ses-03  spatialTS
# 156        630.166667          687.220588     s29  ses-05  spatialTS
# 164        656.787234          778.103896     s29  ses-07  spatialTS
# 172        574.157143          685.750000     s29  ses-09  spatialTS
# 190        692.702703          883.450000     s43  ses-02  spatialTS
# 198        695.772727          795.611765     s43  ses-04  spatialTS
# 206        681.580645          829.596491     s43  ses-06  spatialTS
# 214        670.478261          800.268293     s43  ses-08  spatialTS
# 222        644.558824          792.098592     s43  ses-10  spatialTS
#
#      task_count
# 2           1.0
# 11          2.0
# 19          3.0
# 27          4.0
# 35          5.0
# 53          1.0
# 61          2.0
# 69          3.0
# 77          4.0
# 85          5.0
# 100         1.0
# 108         2.0
# 116         3.0
# 124         4.0
# 132         5.0
# 141         1.0
# 148         2.0
# 156         3.0
# 164         4.0
# 172         5.0
# 190         1.0
# 198         2.0
# 206         3.0
# 214         4.0
# 222         5.0  , 'cuedTS':      cstay_acc  cswitch_tstay_acc  cswitch_tswitch_acc    cstay_rt  \
# 3     0.968254           0.965517             0.985915  709.672131
# 12    0.962963           0.975610             0.938144  698.403846
# 20    0.978723           1.000000             0.958763  608.782609
# 28    1.000000           1.000000             0.948052  611.328125
# 36    0.980392           0.983871             0.924051  668.660000
# 47    0.984375           0.960784             0.844156  637.238095
# 55    1.000000           0.951220             0.927835  593.055556
# 63    0.978723           1.000000             0.927835  612.847826
# 71    0.984127           1.000000             0.929577  595.129032
# 79    0.984127           1.000000             0.943662  550.887097
# 94    0.914894           0.875000             0.845361  585.372093
# 101   0.944444           1.000000             0.917526  579.725490
# 109   0.980392           0.951613             0.936709  613.840000
# 117   0.984375           0.980392             0.870130  539.126984
# 125   0.730159           0.603448             0.732394  637.586957
# 143   0.960784           0.935484             0.936709  714.612245
# 150   0.925926           0.951220             0.907216  657.600000
# 158   0.921875           0.862745             0.831169  638.084746
# 166   0.904762           0.844828             0.802817  598.929825
# 184   0.862745           0.741935             0.746835  846.000000
# 191   0.968750           0.882353             0.883117  712.612903
# 199   0.962963           0.902439             0.927835  697.711538
# 207   1.000000           0.937500             0.845361  677.617021
# 215   0.904762           0.931034             0.929577  658.824561
#
#      cswitch_tstay_rt  cswitch_tswitch_rt subject session    task  task_count
# 3          788.946429          813.000000     s03  ses-02  cuedTS         1.0
# 12         771.100000          781.813187     s03  ses-04  cuedTS         2.0
# 20         636.083333          665.354839     s03  ses-06  cuedTS         3.0
# 28         642.764706          672.383562     s03  ses-08  cuedTS         4.0
# 36         727.163934          778.863014     s03  ses-10  cuedTS         5.0
# 47         670.938776          682.369231     s10  ses-01  cuedTS         1.0
# 55         602.897436          632.811111     s10  ses-03  cuedTS         2.0
# 63         661.708333          695.122222     s10  ses-05  cuedTS         3.0
# 71         657.120690          654.030303     s10  ses-07  cuedTS         4.0
# 79         580.086207          614.567164     s10  ses-09  cuedTS         5.0
# 94         645.166667          676.353659     s19  ses-01  cuedTS         1.0
# 101        633.243902          652.471910     s19  ses-03  cuedTS         2.0
# 109        677.966102          670.581081     s19  ses-05  cuedTS         3.0
# 117        598.020000          638.059701     s19  ses-07  cuedTS         4.0
# 125        699.657143          745.884615     s19  ses-09  cuedTS         5.0
# 143        825.017241          832.972973     s29  ses-02  cuedTS         1.0
# 150        716.282051          775.102273     s29  ses-04  cuedTS         2.0
# 158        771.931818          818.937500     s29  ses-06  cuedTS         3.0
# 166        679.367347          705.666667     s29  ses-08  cuedTS         4.0
# 184        914.717391         1019.525424     s43  ses-01  cuedTS         1.0
# 191        804.422222          794.352941     s43  ses-03  cuedTS         2.0
# 199        855.891892          800.288889     s43  ses-05  cuedTS         3.0
# 207        738.311111          785.000000     s43  ses-07  cuedTS         4.0
# 215        779.074074          764.742424     s43  ses-09  cuedTS         5.0  , 'directedForgetting':       con_acc   pos_acc   neg_acc      con_rt      pos_rt      neg_rt subject  \
# 4    1.000000  0.972222  1.000000  533.666667  584.371429  542.300000     s03
# 13   1.000000  1.000000  1.000000  511.500000  530.897436  530.894737     s03
# 21   1.000000  0.973684  1.000000  555.363636  541.567568  580.750000     s03
# 29   1.000000  1.000000  1.000000  572.192308  580.500000  599.666667     s03
# 37   0.954545  1.000000  0.941176  580.285714  555.243902  545.125000     s03
# 51   1.000000  0.944444  1.000000  524.583333  471.500000  491.450000     s10
# 59   1.000000  0.974359  1.000000  501.227273  463.000000  504.736842     s10
# 67   1.000000  1.000000  1.000000  515.045455  498.804878  533.529412     s10
# 75   1.000000  0.973684  1.000000  530.500000  523.297297  546.800000     s10
# 83   0.961538  0.972222  1.000000  532.520000  499.257143  550.166667     s10
# 95   1.000000  0.976744  0.800000  642.294118  551.380952  744.875000     s19
# 102  1.000000  0.951220  0.941176  593.090909  569.743590  696.625000     s19
# 110  0.961538  0.972222  0.944444  577.960000  513.228571  649.411765     s19
# 118  1.000000  0.921053  0.950000  502.363636  499.571429  530.684211     s19
# 126  1.000000  0.750000  0.750000  602.000000  573.333333  664.933333     s19
# 139  1.000000  0.883721  0.809524  628.125000  679.157895  676.941176     s29
# 146  1.000000  0.951220  0.882353  629.545455  573.102564  672.666667     s29
# 154  0.807692  0.916667  0.666667  619.190476  582.545455  621.666667     s29
# 162  0.909091  0.871795  0.894737  609.550000  579.147059  616.941176     s29
# 170  0.954545  0.894737  0.900000  569.714286  574.735294  661.222222     s29
# 188  0.909091  0.923077  0.894737  614.850000  621.583333  620.352941     s43
# 195  1.000000  0.972222  0.800000  648.541667  644.914286  641.500000     s43
# 203  1.000000  1.000000  1.000000  606.807692  580.250000  638.611111     s43
# 211  1.000000  0.902439  0.882353  593.681818  604.297297  686.733333     s43
# 219  1.000000  0.894737  0.900000  626.363636  599.529412  653.055556     s43
#
#     session                task  task_count
# 4    ses-02  directedForgetting         1.0
# 13   ses-04  directedForgetting         2.0
# 21   ses-06  directedForgetting         3.0
# 29   ses-08  directedForgetting         4.0
# 37   ses-10  directedForgetting         5.0
# 51   ses-02  directedForgetting         1.0
# 59   ses-04  directedForgetting         2.0
# 67   ses-06  directedForgetting         3.0
# 75   ses-08  directedForgetting         4.0
# 83   ses-10  directedForgetting         5.0
# 95   ses-01  directedForgetting         1.0
# 102  ses-03  directedForgetting         2.0
# 110  ses-05  directedForgetting         3.0
# 118  ses-07  directedForgetting         4.0
# 126  ses-09  directedForgetting         5.0
# 139  ses-01  directedForgetting         1.0
# 146  ses-03  directedForgetting         2.0
# 154  ses-05  directedForgetting         3.0
# 162  ses-07  directedForgetting         4.0
# 170  ses-09  directedForgetting         5.0
# 188  ses-02  directedForgetting         1.0
# 195  ses-04  directedForgetting         2.0
# 203  ses-06  directedForgetting         3.0
# 211  ses-08  directedForgetting         4.0
# 219  ses-10  directedForgetting         5.0  , 'flanker':      congruent_acc  incongruent_acc  congruent_rt subject session     task  \
# 5         1.000000         0.986111    515.847222     s03  ses-02  flanker
# 14        0.986486         0.971429    532.054795     s03  ses-04  flanker
# 22        1.000000         1.000000    521.277778     s03  ses-06  flanker
# 30        0.971429         1.000000    525.882353     s03  ses-08  flanker
# 38        0.957143         0.918919    616.089552     s03  ses-10  flanker
# 48        0.013889         0.000000    500.000000     s10  ses-01  flanker
# 56        0.986111         0.986111    429.056338     s10  ses-03  flanker
# 64        0.986486         1.000000    482.863014     s10  ses-05  flanker
# 72        1.000000         0.945946    469.928571     s10  ses-07  flanker
# 80        0.971429         0.932432    451.911765     s10  ses-09  flanker
# 96        0.987500         0.921875    472.240506     s19  ses-01  flanker
# 103       1.000000         1.000000    464.375000     s19  ses-03  flanker
# 111       1.000000         0.942857    519.905405     s19  ses-05  flanker
# 119       0.971429         0.986486    464.882353     s19  ses-07  flanker
# 127       0.671429         0.621622    572.170213     s19  ses-09  flanker
# 144       1.000000         0.944444    561.902778     s29  ses-02  flanker
# 151       0.958333         0.972222    519.768116     s29  ses-04  flanker
# 159       0.971429         0.932432    565.279412     s29  ses-06  flanker
# 167       0.986486         0.957143    513.246575     s29  ses-08  flanker
# 174       0.985714         0.932432    498.550725     s29  ses-10  flanker
# 189       1.000000         1.000000    517.842857     s43  ses-02  flanker
# 196       1.000000         0.986111    522.277778     s43  ses-04  flanker
# 204       0.986486         0.985714    503.561644     s43  ses-06  flanker
# 212       0.986111         0.986111    521.732394     s43  ses-08  flanker
# 220       0.971429         0.972973    550.073529     s43  ses-10  flanker
#
#      task_count
# 5           1.0
# 14          2.0
# 22          3.0
# 30          4.0
# 38          5.0
# 48          1.0
# 56          2.0
# 64          3.0
# 72          4.0
# 80          5.0
# 96          1.0
# 103         2.0
# 111         3.0
# 119         4.0
# 127         5.0
# 144         1.0
# 151         2.0
# 159         3.0
# 167         4.0
# 174         5.0
# 189         1.0
# 196         2.0
# 204         3.0
# 212         4.0
# 220         5.0  , 'nBack':      mismatch_1back_acc  match_1back_acc  mismatch_2back_acc  match_2back_acc  \
# 6              1.000000         1.000000            0.992248         0.967742
# 9              0.992366         0.967742            1.000000         0.939394
# 17             0.966942         0.926829            1.000000         0.931034
# 25             0.935484         0.921053            0.969697         0.857143
# 33             0.921739         0.893617            0.972727         0.800000
# 50             0.984615         0.968750            0.923077         0.933333
# 58             0.980392         0.966667            0.983871         0.944444
# 66             1.000000         1.000000            0.992126         0.969697
# 74             1.000000         0.875000            0.992188         0.937500
# 82             0.983871         0.921053            0.977444         1.000000
# 98             0.976378         0.742857            0.962406         0.370370
# 106            1.000000         0.864865            0.960396         0.728814
# 114            0.991870         0.897436            0.992424         0.785714
# 122            0.968992         0.939394            0.991870         0.810811
# 130            1.000000         0.851852            0.991870         0.945946
# 145            1.000000         0.892857            0.951220         0.810811
# 153            1.000000         0.818182            0.976378         0.787879
# 161            1.000000         0.787879            0.975610         0.675676
# 169            0.985185         0.666667            0.992000         0.685714
# 176            0.914894         0.658537            0.956522         0.711111
# 185            1.000000         0.911765            0.812500         0.656250
# 192            0.991935         0.868421            0.849624         1.000000
# 200            0.907563         0.906977            0.916667         0.714286
# 208            1.000000         0.933333            0.945312         0.750000
# 216            0.982906         0.911111            0.963636         0.860000
#
#      mismatch_1back_rt  match_1back_rt  mismatch_2back_rt  match_2back_rt  \
# 6           482.679389      494.645161         523.484375      520.166667
# 9           544.307692      574.066667         662.165354      726.870968
# 17          589.478632      529.000000         693.732824      704.000000
# 25          574.206897      613.714286         616.414062      678.416667
# 33          548.698113      589.190476         704.102804      661.525000
# 50          560.000000      523.161290         669.291667      548.250000
# 58          476.720000      469.034483         534.983607      466.647059
# 66          521.398438      504.764706         592.785714      557.375000
# 74          478.861538      508.857143         484.204724      486.033333
# 82          493.622951      509.028571         486.869231      528.111111
# 98          566.677419      664.807692         578.242188      771.100000
# 106         542.064000      599.093750         670.701031      747.186047
# 114         578.918033      627.800000         538.282443      588.090909
# 122         541.368000      632.225806         564.188525      612.233333
# 130         546.622222      612.652174         535.139344      608.485714
# 145         593.649254      674.240000         630.111111      680.666667
# 153         485.364341      638.111111         634.161290      658.730769
# 161         489.581395      565.884615         525.983333      605.600000
# 169         449.293233      563.055556         461.661290      510.375000
# 176         464.267442      521.333333         422.300000      503.343750
# 185         568.304688      662.096774         818.730769      823.476190
# 192         549.894309      583.181818         821.415929      769.777778
# 200         633.259259      647.666667         839.380165      773.750000
# 208         501.507576      609.285714         722.636364      767.250000
# 216         497.330435      571.951220         672.726415      764.069767
#
#     subject session   task  task_count
# 6       s03  ses-02  nBack         1.0
# 9       s03  ses-03  nBack         2.0
# 17      s03  ses-05  nBack         3.0
# 25      s03  ses-07  nBack         4.0
# 33      s03  ses-09  nBack         5.0
# 50      s10  ses-01  nBack         1.0
# 58      s10  ses-03  nBack         2.0
# 66      s10  ses-05  nBack         3.0
# 74      s10  ses-07  nBack         4.0
# 82      s10  ses-09  nBack         5.0
# 98      s19  ses-02  nBack         1.0
# 106     s19  ses-04  nBack         2.0
# 114     s19  ses-06  nBack         3.0
# 122     s19  ses-08  nBack         4.0
# 130     s19  ses-10  nBack         5.0
# 145     s29  ses-02  nBack         1.0
# 153     s29  ses-04  nBack         2.0
# 161     s29  ses-06  nBack         3.0
# 169     s29  ses-08  nBack         4.0
# 176     s29  ses-10  nBack         5.0
# 185     s43  ses-01  nBack         1.0
# 192     s43  ses-03  nBack         2.0
# 200     s43  ses-05  nBack         3.0
# 208     s43  ses-07  nBack         4.0
# 216     s43  ses-09  nBack         5.0  , 'stopSignal':      stop_success_count  stop_fail_count  stop_succ_acc  go_succ_acc  \
# 7                  60.0             60.0       0.500000     1.000000
# 15                 62.0             56.0       0.525424     1.000000
# 23                 47.0             41.0       0.534091     0.982955
# 31                 48.0             44.0       0.521739     1.000000
# 39                 47.0             43.0       0.522222     1.000000
# 54                 43.0             45.0       0.488636     1.000000
# 62                 46.0             46.0       0.500000     1.000000
# 70                 59.0             59.0       0.500000     1.000000
# 78                 46.0             44.0       0.511111     0.988506
# 86                 60.0             60.0       0.500000     0.993056
# 97                 62.0             56.0       0.525424     0.945205
# 104                48.0             44.0       0.521739     0.994186
# 112                62.0             58.0       0.516667     0.965278
# 120                68.0             22.0       0.755556     0.505747
# 128                57.0             31.0       0.647727     0.755682
# 142                47.0             41.0       0.534091     1.000000
# 149                37.0             37.0       0.500000     0.986111
# 157                59.0             61.0       0.491667     0.993056
# 165                46.0             46.0       0.500000     0.994186
# 173                59.0             59.0       0.500000     1.000000
# 187                62.0             56.0       0.525424     0.986301
# 194                47.0             43.0       0.522222     1.000000
# 202                49.0             43.0       0.532609     0.976744
# 210                45.0             43.0       0.511364     1.000000
# 218                62.0             58.0       0.516667     1.000000
#
#      stop_fail_rt  go_succ_rt         ssd subject session        task  \
# 7      508.833333  606.451389  388.825758     s03  ses-02  stopSignal
# 15     627.660714  674.171233  471.780303     s03  ses-04  stopSignal
# 23     591.000000  663.184971  449.431818     s03  ses-06  stopSignal
# 31     615.727273  656.319767  438.446970     s03  ses-08  stopSignal
# 39     697.162791  743.764368  516.477273     s03  ses-10  stopSignal
# 54     417.600000  452.210227  211.553030     s10  ses-02  stopSignal
# 62     393.043478  434.750000  162.689394     s10  ses-04  stopSignal
# 70     414.305085  443.904110  160.037879     s10  ses-06  stopSignal
# 78     398.477273  441.587209  192.613636     s10  ses-08  stopSignal
# 86     399.016667  467.790210  178.598485     s10  ses-10  stopSignal
# 97     568.142857  681.615942  383.143939     s19  ses-01  stopSignal
# 104    662.750000  749.438596  552.840909     s19  ses-03  stopSignal
# 112    696.224138  779.251799  558.522727     s19  ses-05  stopSignal
# 120    577.863636  645.659091  669.318182     s19  ses-07  stopSignal
# 128    642.290323  714.037594  563.257576     s19  ses-09  stopSignal
# 142    698.512195  839.289773  547.537879     s29  ses-01  stopSignal
# 149    618.945946  690.809859  427.064220     s29  ses-03  stopSignal
# 157    528.180328  576.650350  279.734848     s29  ses-05  stopSignal
# 165    482.739130  593.473684  277.840909     s29  ses-07  stopSignal
# 173    469.152542  541.760274  283.901515     s29  ses-09  stopSignal
# 187    752.375000  910.784722  589.962121     s43  ses-01  stopSignal
# 194    612.720930  684.534483  363.068182     s43  ses-03  stopSignal
# 202    622.790698  684.357143  408.901515     s43  ses-05  stopSignal
# 210    654.744186  719.755682  449.053030     s43  ses-07  stopSignal
# 218    682.017241  798.756944  507.386364     s43  ses-09  stopSignal
#
#      task_count
# 7           1.0
# 15          2.0
# 23          3.0
# 31          4.0
# 39          5.0
# 54          1.0
# 62          2.0
# 70          3.0
# 78          4.0
# 86          5.0
# 97          1.0
# 104         2.0
# 112         3.0
# 120         4.0
# 128         5.0
# 142         1.0
# 149         2.0
# 157         3.0
# 165         4.0
# 173         5.0
# 187         1.0
# 194         2.0
# 202         3.0
# 210         4.0
# 218         5.0  , 'directedForgettingWFlanker':      pos_incongruent_acc  neg_incongruent_acc  con_incongruent_acc  \
# 40              0.961538             0.933333             0.812500
# 43              0.862069             1.000000             0.800000
# 87              0.931034             0.933333             1.000000
# 90              0.961538             1.000000             1.000000
# 135             0.692308             0.866667             0.875000
# 177             0.909091             1.000000             1.000000
# 180             0.807692             0.866667             1.000000
# 225             0.965517             0.866667             0.933333
#
#      pos_congruent_acc  neg_congruent_acc  con_congruent_acc  \
# 40            0.878788           0.800000           0.933333
# 43            0.833333           0.866667           0.875000
# 87            0.966667           1.000000           1.000000
# 90            0.939394           0.933333           1.000000
# 135           0.696970           0.800000           0.866667
# 177           1.000000           0.857143           1.000000
# 180           0.818182           0.866667           1.000000
# 225           0.933333           1.000000           1.000000
#
#      pos_incongruent_rt  neg_incongruent_rt  con_incongruent_rt  \
# 40           657.040000          666.357143          722.615385
# 43           685.440000          681.866667          586.333333
# 87           554.185185          568.000000          548.466667
# 90           494.560000          523.933333          506.312500
# 135          583.722222          612.615385          604.928571
# 177          675.800000          721.250000          582.571429
# 180          605.047619          633.230769          612.250000
# 225          720.107143          686.846154          586.285714
#
#      pos_congruent_rt  neg_congruent_rt  con_congruent_rt subject session  \
# 40         648.068966        769.083333        606.071429     s03  ses-11
# 43         602.880000        706.769231        565.857143     s03  ses-12
# 87         511.103448        587.200000        541.062500     s10  ses-11
# 90         428.580645        502.071429        486.200000     s10  ses-12
# 135        611.434783        642.750000        590.153846     s19  ses-12
# 177        631.750000        668.500000        551.142857     s29  ses-11
# 180        625.259259        700.923077        630.133333     s29  ses-12
# 225        636.571429        647.333333        593.687500     s43  ses-12
#
#                            task  task_count
# 40   directedForgettingWFlanker         1.0
# 43   directedForgettingWFlanker         2.0
# 87   directedForgettingWFlanker         1.0
# 90   directedForgettingWFlanker         2.0
# 135  directedForgettingWFlanker         1.0
# 177  directedForgettingWFlanker         1.0
# 180  directedForgettingWFlanker         2.0
# 225  directedForgettingWFlanker         1.0  , 'stopSignalWDirectedForgetting':             ssd  pos_stop_acc  pos_go_acc  neg_stop_acc  neg_go_acc  \
# 41   552.083333      0.541667    1.000000      0.500000    1.000000
# 44   411.111111      0.285714    1.000000      0.500000    0.933333
# 88   268.750000      0.357143    1.000000      0.700000    1.000000
# 91   237.500000      0.291667    1.000000      0.714286    1.000000
# 133  300.694444      0.500000    0.979167      0.428571    0.958333
# 136  245.138889      0.285714    1.000000      0.500000    1.000000
# 178  297.222222      0.416667    1.000000      0.642857    1.000000
# 181  257.638889      0.571429    1.000000      0.300000    0.966667
# 224  402.083333      0.714286    0.682927      0.800000    0.666667
# 227  343.750000      0.500000    1.000000      0.642857    1.000000
#
#      con_stop_acc  con_go_acc  pos_go_succ_rt  pos_stop_fail_rt  \
# 41       0.416667    1.000000      604.875000        564.272727
# 44       0.727273    1.000000      659.853659        597.400000
# 88       0.545455    1.000000      471.756098        439.888889
# 91       0.583333    1.000000      461.770833        420.529412
# 133      0.583333    1.000000      584.085106        502.250000
# 136      0.636364    0.973684      566.731707        486.000000
# 178      0.500000    1.000000      701.041667        578.642857
# 181      0.454545    0.973684      546.414634        490.166667
# 224      0.454545    0.842105      764.750000        619.250000
# 227      0.500000    1.000000      672.250000        602.500000
#
#      neg_go_succ_rt  neg_stop_fail_rt  con_go_succ_rt  con_stop_fail_rt  \
# 41       640.583333        614.285714      676.727273        534.142857
# 44       768.392857        514.400000      683.447368        567.333333
# 88       537.133333        525.000000      533.973684        524.400000
# 91       525.208333        528.250000      499.181818        474.200000
# 133      627.043478        625.250000      655.090909        598.600000
# 136      585.800000        459.400000      552.729730        479.500000
# 178      752.291667        569.800000      617.954545        694.000000
# 181      581.206897        451.857143      553.783784        519.166667
# 224      761.550000        728.500000      664.781250        803.000000
# 227      717.083333        653.600000      635.227273        600.333333
#
#     subject session                           task  task_count
# 41      s03  ses-11  stopSignalWDirectedForgetting         1.0
# 44      s03  ses-12  stopSignalWDirectedForgetting         2.0
# 88      s10  ses-11  stopSignalWDirectedForgetting         1.0
# 91      s10  ses-12  stopSignalWDirectedForgetting         2.0
# 133     s19  ses-11  stopSignalWDirectedForgetting         1.0
# 136     s19  ses-12  stopSignalWDirectedForgetting         2.0
# 178     s29  ses-11  stopSignalWDirectedForgetting         1.0
# 181     s29  ses-12  stopSignalWDirectedForgetting         2.0
# 224     s43  ses-11  stopSignalWDirectedForgetting         1.0
# 227     s43  ses-12  stopSignalWDirectedForgetting         2.0  , 'stopSignalWFlanker':             ssd  congruent_stop_acc  congruent_go_acc  incongruent_stop_acc  \
# 42   473.541667            0.532258          1.000000              0.508197
# 45   531.458333            0.553191          0.896104              0.609756
# 89   256.458333            0.510638          1.000000              0.536585
# 92   251.875000            0.516129          1.000000              0.475410
# 134  498.125000            0.564516          0.929825              0.524590
# 137  304.791667            0.468085          0.909091              0.487805
# 179  267.916667            0.450000          1.000000              0.523810
# 182  390.208333            0.516129          1.000000              0.524590
# 223  478.541667            0.553191          1.000000              0.560976
# 226  527.291667            0.532258          1.000000              0.524590
#
#      incongruent_go_acc  congruent_go_succ_rt  congruent_stop_fail_rt  \
# 42             0.983333            651.017544              603.793103
# 45             0.946667            778.956522              698.476190
# 89             1.000000            447.051948              410.478261
# 92             1.000000            466.912281              421.133333
# 134            0.866667            748.698113              688.296296
# 137            0.960000            505.442857              494.160000
# 179            1.000000            577.628571              497.363636
# 182            1.000000            699.157895              555.466667
# 223            1.000000            737.324675              667.333333
# 226            0.983333            809.263158              671.655172
#
#      incongruent_go_succ_rt  incongruent_stop_fail_rt subject session  \
# 42               701.644068                618.033333     s03  ses-11
# 45               802.014085                757.000000     s03  ses-12
# 89               478.733333                473.631579     s10  ses-11
# 92               499.000000                443.281250     s10  ses-12
# 134              733.480769                690.896552     s19  ses-11
# 137              549.125000                488.523810     s19  ses-12
# 179              546.909091                544.400000     s29  ses-11
# 182              679.683333                596.310345     s29  ses-12
# 223              749.026667                698.500000     s43  ses-11
# 226              789.084746                728.655172     s43  ses-12
#
#                    task  task_count
# 42   stopSignalWFlanker         1.0
# 45   stopSignalWFlanker         2.0
# 89   stopSignalWFlanker         1.0
# 92   stopSignalWFlanker         2.0
# 134  stopSignalWFlanker         1.0
# 137  stopSignalWFlanker         2.0
# 179  stopSignalWFlanker         1.0
# 182  stopSignalWFlanker         2.0
# 223  stopSignalWFlanker         1.0
# 226  stopSignalWFlanker         2.0  }

# %%
# for task in task_list:
#     curr_df = dfs_task_list[task]
#     for acc_name in task_acc_list[task]:
#         plt.figure(figsize=(12, 6))
#         sns.lineplot(data=curr_df, x='task_count', y=acc_name, hue='subject', marker='o')
        
#         # Aesthetics
#         plt.title(f'{task}: Participant {acc_name} Across Encounters')
#         plt.xlabel('Task Count')
#         plt.ylabel(f'Performance: {acc_name}')
#         plt.legend(title='Participants')
#         plt.grid()
#         plt.show()

for task in task_list:
    curr_df = dfs_task_list[task]
    

    num_acc_names = len(task_acc_list[task])
    num_rows = int(np.ceil(num_acc_names / 2))

    fig, axes = plt.subplots(num_rows, 2, figsize=(12, 4 * num_rows), sharex=True)
    
    axes = axes.flatten()

    for i, acc_name in enumerate(task_acc_list[task]):
        # Plot on subplot
        sns.lineplot(data=curr_df, x='task_count', y=acc_name, hue='subject', marker='o', ax=axes[i])
        
        axes[i].set_title(f'{task}: Participant {acc_name} Across Encounters')
        axes[i].set_ylabel(f'Performance: {acc_name}')
        axes[i].legend(title='Participants')
        axes[i].grid()

    # erase unused subplots
    for j in range(num_acc_names, num_rows * 2):
        axes[j].axis('off')

    axes[-1].set_xlabel('Task Count')
    plt.tight_layout()
    
    plt.show()

# %%
# Fixed Effects Parcellation
# Parcellates fixed effects maps with the smorgasbord atlas (includes both cortical and subcortical) 
# and saves the df in smor_parcel_dfs_fixed

# 1. Load each subject's fixed effects map individually (and save this parcellated map)
# 2. Parcellate each subject's map (average t-stats within parcels per subject) and saves this
# 3. Average the parcel values across subjects and saves this

# %%
import os
import numpy as np
import pandas as pd
import nibabel as nib
import nilearn
import json
import datetime
import pickle
import seaborn as sns
import gc
import psutil
import math
import scipy.stats as stats
from matplotlib.patches import Patch
from nilearn import plotting
from nilearn.glm.first_level import FirstLevelModel
from nilearn.glm.second_level import SecondLevelModel
from nilearn.glm import threshold_stats_img
from nilearn.image import concat_imgs, mean_img, index_img
from nilearn.reporting import make_glm_report
from nilearn import masking, image
from nilearn import datasets
from scipy.stats import pearsonr
import matplotlib.pyplot as plt
from collections import defaultdict
from nilearn.maskers import NiftiLabelsMasker
from sklearn.utils import Bunch

# Import shared utilities and configuration
# need to do it this way because in a sub-directory (later turn config and utils into part of a package)
from utils import (
    TASKS, CONTRASTS, SUBJECTS, SESSIONS, ENCOUNTERS,
    build_first_level_contrast_map_path, build_fixed_effects_path, is_valid_contrast_map, clean_z_map_data,
    convert_to_regular_dict, create_smor_atlas,load_smor_atlas, load_schaefer_atlas, cleanup_memory, standardize_mask
)
from config import BASE_DIR, OUTPUT_DIRS

# %%
encounters = ['01', '02','03','04','05']

# compile all requested contrasts into one list
compiled_req_contrasts = []
for task in TASKS:
    for contrast in CONTRASTS[task]:
        if (contrast not in compiled_req_contrasts):
            compiled_req_contrasts.append(contrast)

# %%
# get smorgasbord atlas
# GET ATLASES:
smor_atlas_path = 'processed_data_dfs/smor_parcel_dfs/smorgasbord_atlas_files/smorgasbord_atlas.pkl'
if not os.path.exists(smor_atlas_path):
    print("Smorgasbord atlas not found. Creating new atlas...")
    create_smor_atlas()
else:
    print("atlas already exists")
    smorgasbord_atlas = load_smor_atlas()
SMORG_IMG = smorgasbord_atlas.maps
SMORG_DATA = SMORG_IMG.get_fdata()
# Out:
# atlas already exists
# Loading Smorgasbord atlas...
# Atlas loaded with 429 regions
# Atlas shape: (193, 229, 193)

# %% [markdown]
# # Load fixed effect maps

# %%
# load the fixed effects maps
# LOADING ALL FIXED EFFECTS:
# Organize by subject, then parcellate each subject individually
# Then average parcel values across subjects (not voxel-wise averaging)

# Organize fixed effects maps by subject (not averaged)
fe_all_contrast_maps = defaultdict(lambda: defaultdict(lambda: defaultdict(dict)))

for task in TASKS:
    for contrast_name in CONTRASTS[task]:
        for subject in SUBJECTS:
            # filename = f'{subject}_task-{task}_contrast-{contrast_name}_rtmodel-rt_centered_stat-fixed-effects.nii.gz'
            # contrast_map_path = os.path.join(BASE_DIR, INPUT_LEVEL, subject, task,'fixed_effects',filename)

            contrast_map_path = build_fixed_effects_path(BASE_DIR, subject, task, contrast_name, "z")

            if os.path.exists(contrast_map_path):
                try:
                    # Load the map for this subject
                    fe_all_contrast_maps[task][contrast_name][subject] = nib.load(contrast_map_path)
                    print(f"Loaded fixed effects map for {subject}/{task}/{contrast_name}")
                except Exception as e:
                    print(f"Error loading {contrast_map_path}: {e}")
            else:
                print(f"{contrast_map_path} does not exist.")

print(f"\nFixed effects maps organized by subject")
print(f"Structure: task -> contrast -> subject -> NiftiImage")
# Out:
# Loaded fixed effects map for sub-s03/nBack/twoBack-oneBack
# Loaded fixed effects map for sub-s10/nBack/twoBack-oneBack
# Loaded fixed effects map for sub-s19/nBack/twoBack-oneBack
# Loaded fixed effects map for sub-s29/nBack/twoBack-oneBack
# Loaded fixed effects map for sub-s43/nBack/twoBack-oneBack
# Loaded fixed effects map for sub-s03/nBack/match-mismatch
# Loaded fixed effects map for sub-s10/nBack/match-mismatch
# Loaded fixed effects map for sub-s19/nBack/match-mismatch
# Loaded fixed effects map for sub-s29/nBack/match-mismatch
# Loaded fixed effects map for sub-s43/nBack/match-mismatch
# Loaded fixed effects map for sub-s03/nBack/task-baseline
# Loaded fixed effects map for sub-s10/nBack/task-baseline
# Loaded fixed effects map for sub-s19/nBack/task-baseline
# Loaded fixed effects map for sub-s29/nBack/task-baseline
# Loaded fixed effects map for sub-s43/nBack/task-baseline
# Loaded fixed effects map for sub-s03/nBack/response_time
# Loaded fixed effects map for sub-s10/nBack/response_time
# Loaded fixed effects map for sub-s19/nBack/response_time
# Loaded fixed effects map for sub-s29/nBack/response_time
# Loaded fixed effects map for sub-s43/nBack/response_time
# Loaded fixed effects map for sub-s03/flanker/incongruent-congruent
# Loaded fixed effects map for sub-s10/flanker/incongruent-congruent
# Loaded fixed effects map for sub-s19/flanker/incongruent-congruent
# Loaded fixed effects map for sub-s29/flanker/incongruent-congruent
# Loaded fixed effects map for sub-s43/flanker/incongruent-congruent
# Loaded fixed effects map for sub-s03/flanker/task-baseline
# Loaded fixed effects map for sub-s10/flanker/task-baseline
# Loaded fixed effects map for sub-s19/flanker/task-baseline
# Loaded fixed effects map for sub-s29/flanker/task-baseline
# Loaded fixed effects map for sub-s43/flanker/task-baseline
# Loaded fixed effects map for sub-s03/directedForgetting/neg-con
# Loaded fixed effects map for sub-s10/directedForgetting/neg-con
# Loaded fixed effects map for sub-s19/directedForgetting/neg-con
# Loaded fixed effects map for sub-s29/directedForgetting/neg-con
# Loaded fixed effects map for sub-s43/directedForgetting/neg-con
# Loaded fixed effects map for sub-s03/directedForgetting/task-baseline
# Loaded fixed effects map for sub-s10/directedForgetting/task-baseline
# Loaded fixed effects map for sub-s19/directedForgetting/task-baseline
# Loaded fixed effects map for sub-s29/directedForgetting/task-baseline
# Loaded fixed effects map for sub-s43/directedForgetting/task-baseline
# Loaded fixed effects map for sub-s03/directedForgetting/response_time
# Loaded fixed effects map for sub-s10/directedForgetting/response_time
# Loaded fixed effects map for sub-s19/directedForgetting/response_time
# Loaded fixed effects map for sub-s29/directedForgetting/response_time
# Loaded fixed effects map for sub-s43/directedForgetting/response_time
# Loaded fixed effects map for sub-s03/goNogo/nogo_success-go
# Loaded fixed effects map for sub-s10/goNogo/nogo_success-go
# Loaded fixed effects map for sub-s19/goNogo/nogo_success-go
# Loaded fixed effects map for sub-s29/goNogo/nogo_success-go
# Loaded fixed effects map for sub-s43/goNogo/nogo_success-go
# Loaded fixed effects map for sub-s03/goNogo/nogo_success
# Loaded fixed effects map for sub-s10/goNogo/nogo_success
# Loaded fixed effects map for sub-s19/goNogo/nogo_success
# Loaded fixed effects map for sub-s29/goNogo/nogo_success
# Loaded fixed effects map for sub-s43/goNogo/nogo_success
# Loaded fixed effects map for sub-s03/goNogo/task-baseline
# Loaded fixed effects map for sub-s10/goNogo/task-baseline
# Loaded fixed effects map for sub-s19/goNogo/task-baseline
# Loaded fixed effects map for sub-s29/goNogo/task-baseline
# Loaded fixed effects map for sub-s43/goNogo/task-baseline
# /oak/stanford/groups/russpold/data/network_grant/discovery_BIDS_20250402/derivatives/dataset-networkDiscovery_model-lev1_space-MNI_withinMaskThreshold-1.0_rtmodel-RTDur/sub-s03/task-goNogo/fixed_effects/sub-s03_task-goNogo_contrast-response_time_rtmodel-RTDur_stat-fixed-effects-z_score.nii.gz does not exist.
# /oak/stanford/groups/russpold/data/network_grant/discovery_BIDS_20250402/derivatives/dataset-networkDiscovery_model-lev1_space-MNI_withinMaskThreshold-1.0_rtmodel-RTDur/sub-s10/task-goNogo/fixed_effects/sub-s10_task-goNogo_contrast-response_time_rtmodel-RTDur_stat-fixed-effects-z_score.nii.gz does not exist.
# /oak/stanford/groups/russpold/data/network_grant/discovery_BIDS_20250402/derivatives/dataset-networkDiscovery_model-lev1_space-MNI_withinMaskThreshold-1.0_rtmodel-RTDur/sub-s19/task-goNogo/fixed_effects/sub-s19_task-goNogo_contrast-response_time_rtmodel-RTDur_stat-fixed-effects-z_score.nii.gz does not exist.
# /oak/stanford/groups/russpold/data/network_grant/discovery_BIDS_20250402/derivatives/dataset-networkDiscovery_model-lev1_space-MNI_withinMaskThreshold-1.0_rtmodel-RTDur/sub-s29/task-goNogo/fixed_effects/sub-s29_task-goNogo_contrast-response_time_rtmodel-RTDur_stat-fixed-effects-z_score.nii.gz does not exist.
# /oak/stanford/groups/russpold/data/network_grant/discovery_BIDS_20250402/derivatives/dataset-networkDiscovery_model-lev1_space-MNI_withinMaskThreshold-1.0_rtmodel-RTDur/sub-s43/task-goNogo/fixed_effects/sub-s43_task-goNogo_contrast-response_time_rtmodel-RTDur_stat-fixed-effects-z_score.nii.gz does not exist.
# Loaded fixed effects map for sub-s03/shapeMatching/DDD
# Loaded fixed effects map for sub-s10/shapeMatching/DDD
# Loaded fixed effects map for sub-s19/shapeMatching/DDD
# Loaded fixed effects map for sub-s29/shapeMatching/DDD
# Loaded fixed effects map for sub-s43/shapeMatching/DDD
# Loaded fixed effects map for sub-s03/shapeMatching/DDS
# Loaded fixed effects map for sub-s10/shapeMatching/DDS
# Loaded fixed effects map for sub-s19/shapeMatching/DDS
# Loaded fixed effects map for sub-s29/shapeMatching/DDS
# Loaded fixed effects map for sub-s43/shapeMatching/DDS
# Loaded fixed effects map for sub-s03/shapeMatching/DNN
# Loaded fixed effects map for sub-s10/shapeMatching/DNN
# Loaded fixed effects map for sub-s19/shapeMatching/DNN
# Loaded fixed effects map for sub-s29/shapeMatching/DNN
# Loaded fixed effects map for sub-s43/shapeMatching/DNN
# Loaded fixed effects map for sub-s03/shapeMatching/DSD
# Loaded fixed effects map for sub-s10/shapeMatching/DSD
# Loaded fixed effects map for sub-s19/shapeMatching/DSD
# Loaded fixed effects map for sub-s29/shapeMatching/DSD
# Loaded fixed effects map for sub-s43/shapeMatching/DSD
# Loaded fixed effects map for sub-s03/shapeMatching/main_vars
# Loaded fixed effects map for sub-s10/shapeMatching/main_vars
# Loaded fixed effects map for sub-s19/shapeMatching/main_vars
# Loaded fixed effects map for sub-s29/shapeMatching/main_vars
# Loaded fixed effects map for sub-s43/shapeMatching/main_vars
# Loaded fixed effects map for sub-s03/shapeMatching/SDD
# Loaded fixed effects map for sub-s10/shapeMatching/SDD
# Loaded fixed effects map for sub-s19/shapeMatching/SDD
# Loaded fixed effects map for sub-s29/shapeMatching/SDD
# Loaded fixed effects map for sub-s43/shapeMatching/SDD
# Loaded fixed effects map for sub-s03/shapeMatching/SNN
# Loaded fixed effects map for sub-s10/shapeMatching/SNN
# Loaded fixed effects map for sub-s19/shapeMatching/SNN
# Loaded fixed effects map for sub-s29/shapeMatching/SNN
# Loaded fixed effects map for sub-s43/shapeMatching/SNN
# Loaded fixed effects map for sub-s03/shapeMatching/SSS
# Loaded fixed effects map for sub-s10/shapeMatching/SSS
# Loaded fixed effects map for sub-s19/shapeMatching/SSS
# Loaded fixed effects map for sub-s29/shapeMatching/SSS
# Loaded fixed effects map for sub-s43/shapeMatching/SSS
# Loaded fixed effects map for sub-s03/shapeMatching/task-baseline
# Loaded fixed effects map for sub-s10/shapeMatching/task-baseline
# Loaded fixed effects map for sub-s19/shapeMatching/task-baseline
# Loaded fixed effects map for sub-s29/shapeMatching/task-baseline
# Loaded fixed effects map for sub-s43/shapeMatching/task-baseline
# Loaded fixed effects map for sub-s03/shapeMatching/response_time
# Loaded fixed effects map for sub-s10/shapeMatching/response_time
# Loaded fixed effects map for sub-s19/shapeMatching/response_time
# Loaded fixed effects map for sub-s29/shapeMatching/response_time
# Loaded fixed effects map for sub-s43/shapeMatching/response_time
# Loaded fixed effects map for sub-s03/stopSignal/go
# Loaded fixed effects map for sub-s10/stopSignal/go
# Loaded fixed effects map for sub-s19/stopSignal/go
# Loaded fixed effects map for sub-s29/stopSignal/go
# Loaded fixed effects map for sub-s43/stopSignal/go
# Loaded fixed effects map for sub-s03/stopSignal/stop_failure-go
# Loaded fixed effects map for sub-s10/stopSignal/stop_failure-go
# Loaded fixed effects map for sub-s19/stopSignal/stop_failure-go
# Loaded fixed effects map for sub-s29/stopSignal/stop_failure-go
# Loaded fixed effects map for sub-s43/stopSignal/stop_failure-go
# Loaded fixed effects map for sub-s03/stopSignal/stop_failure
# Loaded fixed effects map for sub-s10/stopSignal/stop_failure
# Loaded fixed effects map for sub-s19/stopSignal/stop_failure
# Loaded fixed effects map for sub-s29/stopSignal/stop_failure
# Loaded fixed effects map for sub-s43/stopSignal/stop_failure
# Loaded fixed effects map for sub-s03/stopSignal/stop_failure-stop_success
# Loaded fixed effects map for sub-s10/stopSignal/stop_failure-stop_success
# Loaded fixed effects map for sub-s19/stopSignal/stop_failure-stop_success
# Loaded fixed effects map for sub-s29/stopSignal/stop_failure-stop_success
# Loaded fixed effects map for sub-s43/stopSignal/stop_failure-stop_success
# Loaded fixed effects map for sub-s03/stopSignal/stop_success-go
# Loaded fixed effects map for sub-s10/stopSignal/stop_success-go
# Loaded fixed effects map for sub-s19/stopSignal/stop_success-go
# Loaded fixed effects map for sub-s29/stopSignal/stop_success-go
# Loaded fixed effects map for sub-s43/stopSignal/stop_success-go
# Loaded fixed effects map for sub-s03/stopSignal/stop_success
# Loaded fixed effects map for sub-s10/stopSignal/stop_success
# Loaded fixed effects map for sub-s19/stopSignal/stop_success
# Loaded fixed effects map for sub-s29/stopSignal/stop_success
# Loaded fixed effects map for sub-s43/stopSignal/stop_success
# Loaded fixed effects map for sub-s03/stopSignal/stop_success-stop_failure
# Loaded fixed effects map for sub-s10/stopSignal/stop_success-stop_failure
# Loaded fixed effects map for sub-s19/stopSignal/stop_success-stop_failure
# Loaded fixed effects map for sub-s29/stopSignal/stop_success-stop_failure
# Loaded fixed effects map for sub-s43/stopSignal/stop_success-stop_failure
# Loaded fixed effects map for sub-s03/stopSignal/task-baseline
# Loaded fixed effects map for sub-s10/stopSignal/task-baseline
# Loaded fixed effects map for sub-s19/stopSignal/task-baseline
# Loaded fixed effects map for sub-s29/stopSignal/task-baseline
# Loaded fixed effects map for sub-s43/stopSignal/task-baseline
# /oak/stanford/groups/russpold/data/network_grant/discovery_BIDS_20250402/derivatives/dataset-networkDiscovery_model-lev1_space-MNI_withinMaskThreshold-1.0_rtmodel-RTDur/sub-s03/task-stopSignal/fixed_effects/sub-s03_task-stopSignal_contrast-response_time_rtmodel-RTDur_stat-fixed-effects-z_score.nii.gz does not exist.
# /oak/stanford/groups/russpold/data/network_grant/discovery_BIDS_20250402/derivatives/dataset-networkDiscovery_model-lev1_space-MNI_withinMaskThreshold-1.0_rtmodel-RTDur/sub-s10/task-stopSignal/fixed_effects/sub-s10_task-stopSignal_contrast-response_time_rtmodel-RTDur_stat-fixed-effects-z_score.nii.gz does not exist.
# /oak/stanford/groups/russpold/data/network_grant/discovery_BIDS_20250402/derivatives/dataset-networkDiscovery_model-lev1_space-MNI_withinMaskThreshold-1.0_rtmodel-RTDur/sub-s19/task-stopSignal/fixed_effects/sub-s19_task-stopSignal_contrast-response_time_rtmodel-RTDur_stat-fixed-effects-z_score.nii.gz does not exist.
# /oak/stanford/groups/russpold/data/network_grant/discovery_BIDS_20250402/derivatives/dataset-networkDiscovery_model-lev1_space-MNI_withinMaskThreshold-1.0_rtmodel-RTDur/sub-s29/task-stopSignal/fixed_effects/sub-s29_task-stopSignal_contrast-response_time_rtmodel-RTDur_stat-fixed-effects-z_score.nii.gz does not exist.
# /oak/stanford/groups/russpold/data/network_grant/discovery_BIDS_20250402/derivatives/dataset-networkDiscovery_model-lev1_space-MNI_withinMaskThreshold-1.0_rtmodel-RTDur/sub-s43/task-stopSignal/fixed_effects/sub-s43_task-stopSignal_contrast-response_time_rtmodel-RTDur_stat-fixed-effects-z_score.nii.gz does not exist.
# Loaded fixed effects map for sub-s03/cuedTS/cue_switch_cost
# Loaded fixed effects map for sub-s10/cuedTS/cue_switch_cost
# Loaded fixed effects map for sub-s19/cuedTS/cue_switch_cost
# Loaded fixed effects map for sub-s29/cuedTS/cue_switch_cost
# Loaded fixed effects map for sub-s43/cuedTS/cue_switch_cost
# Loaded fixed effects map for sub-s03/cuedTS/task_switch_cost
# Loaded fixed effects map for sub-s10/cuedTS/task_switch_cost
# Loaded fixed effects map for sub-s19/cuedTS/task_switch_cost
# Loaded fixed effects map for sub-s29/cuedTS/task_switch_cost
# Loaded fixed effects map for sub-s43/cuedTS/task_switch_cost
# Loaded fixed effects map for sub-s03/cuedTS/task_switch_cue_switch-task_stay_cue_stay
# Loaded fixed effects map for sub-s10/cuedTS/task_switch_cue_switch-task_stay_cue_stay
# Loaded fixed effects map for sub-s19/cuedTS/task_switch_cue_switch-task_stay_cue_stay
# Loaded fixed effects map for sub-s29/cuedTS/task_switch_cue_switch-task_stay_cue_stay
# Loaded fixed effects map for sub-s43/cuedTS/task_switch_cue_switch-task_stay_cue_stay
# Loaded fixed effects map for sub-s03/cuedTS/task-baseline
# Loaded fixed effects map for sub-s10/cuedTS/task-baseline
# Loaded fixed effects map for sub-s19/cuedTS/task-baseline
# Loaded fixed effects map for sub-s29/cuedTS/task-baseline
# Loaded fixed effects map for sub-s43/cuedTS/task-baseline
# Loaded fixed effects map for sub-s03/cuedTS/response_time
# Loaded fixed effects map for sub-s10/cuedTS/response_time
# Loaded fixed effects map for sub-s19/cuedTS/response_time
# Loaded fixed effects map for sub-s29/cuedTS/response_time
# Loaded fixed effects map for sub-s43/cuedTS/response_time
# Loaded fixed effects map for sub-s03/spatialTS/cue_switch_cost
# Loaded fixed effects map for sub-s10/spatialTS/cue_switch_cost
# Loaded fixed effects map for sub-s19/spatialTS/cue_switch_cost
# Loaded fixed effects map for sub-s29/spatialTS/cue_switch_cost
# Loaded fixed effects map for sub-s43/spatialTS/cue_switch_cost
# Loaded fixed effects map for sub-s03/spatialTS/task_switch_cost
# Loaded fixed effects map for sub-s10/spatialTS/task_switch_cost
# Loaded fixed effects map for sub-s19/spatialTS/task_switch_cost
# Loaded fixed effects map for sub-s29/spatialTS/task_switch_cost
# Loaded fixed effects map for sub-s43/spatialTS/task_switch_cost
# Loaded fixed effects map for sub-s03/spatialTS/task_switch_cue_switch-task_stay_cue_stay
# Loaded fixed effects map for sub-s10/spatialTS/task_switch_cue_switch-task_stay_cue_stay
# Loaded fixed effects map for sub-s19/spatialTS/task_switch_cue_switch-task_stay_cue_stay
# Loaded fixed effects map for sub-s29/spatialTS/task_switch_cue_switch-task_stay_cue_stay
# Loaded fixed effects map for sub-s43/spatialTS/task_switch_cue_switch-task_stay_cue_stay
# Loaded fixed effects map for sub-s03/spatialTS/task-baseline
# Loaded fixed effects map for sub-s10/spatialTS/task-baseline
# Loaded fixed effects map for sub-s19/spatialTS/task-baseline
# Loaded fixed effects map for sub-s29/spatialTS/task-baseline
# Loaded fixed effects map for sub-s43/spatialTS/task-baseline
# Loaded fixed effects map for sub-s03/spatialTS/response_time
# Loaded fixed effects map for sub-s10/spatialTS/response_time
# Loaded fixed effects map for sub-s19/spatialTS/response_time
# Loaded fixed effects map for sub-s29/spatialTS/response_time
# Loaded fixed effects map for sub-s43/spatialTS/response_time
#
# Fixed effects maps organized by subject
# Structure: task -> contrast -> subject -> NiftiImage

# %% [markdown]
# # Parcellate across all task/contrasts/subjects

# %%
# Check structure of loaded fixed effects maps
print("Sample structure check:")
for task in list(TASKS)[:2]:  # Just check first 2 tasks
    for contrast in list(CONTRASTS[task])[:2]:  # Just first 2 contrasts
        if task in fe_all_contrast_maps and contrast in fe_all_contrast_maps[task]:
            subjects_loaded = list(fe_all_contrast_maps[task][contrast].keys())
            print(f"{task}/{contrast}: {len(subjects_loaded)} subjects - {subjects_loaded}")
# Out:
# Sample structure check:
# nBack/twoBack-oneBack: 5 subjects - ['sub-s03', 'sub-s10', 'sub-s19', 'sub-s29', 'sub-s43']
# nBack/match-mismatch: 5 subjects - ['sub-s03', 'sub-s10', 'sub-s19', 'sub-s29', 'sub-s43']
# flanker/incongruent-congruent: 5 subjects - ['sub-s03', 'sub-s10', 'sub-s19', 'sub-s29', 'sub-s43']
# flanker/task-baseline: 5 subjects - ['sub-s03', 'sub-s10', 'sub-s19', 'sub-s29', 'sub-s43']

# %%
encounters = ['01', '02','03','04','05']

def save_fixed_subset_of_parcels(run_num, date, atlas='schaefer', file_type = "default"):
    """
    Extract parcel-wise activation values from fixed effects maps.
    
    1. Parcellate each subject's fixed effects map individually (average within parcels)
    2. Average the parcel values across subjects
    
    Parameters:
    -----------
    subs_requested : list
        Subject IDs to process
    run_num : str/int
        Run identifier for output filename
    atlas : str
        Either 'schaefer' or 'smor'
    data: str
        Added as processed date
    """
    parcel_dict = {}
    
    # Select atlas
    if atlas == 'schaefer':
        current_atlas = load_schaefer_atlas()
        atlas_name = 'schaefer400'
        print(f'doing {atlas_name}')
    else:
        current_atlas = load_smor_atlas()
        atlas_name = 'smor_parcel'
        print(f'doing {atlas_name}')

    for curr_subj in SUBJECTS:
        # STEP 1: parcellate each subjects task/contrast fixed effect map
        parcel_dict[curr_subj] = {}
        
        for curr_task in CONTRASTS:
            parcel_dict[curr_subj][curr_task] = {}
    
            for curr_contrast in CONTRASTS[curr_task]:
                parcel_dict[curr_subj][curr_task][curr_contrast] = {}
    
                print(f"Processing: {curr_subj} - {curr_task} - {curr_contrast}")
    
                try:
                    fmri_img = fe_all_contrast_maps[curr_task][curr_contrast][curr_subj]
                    print(f"fMRI data loaded | Shape: {fmri_img.shape}")
    
                    # Create the masker and get regional avg activation
                    masker = NiftiLabelsMasker(
                        labels_img=current_atlas.maps,
                        standardize=False, 
                        memory='nilearn_cache',
                        strategy='mean'  # Average activation within each region
                    )
                    
                    # Extract regional values
                    regional_values = masker.fit_transform(fmri_img)
                    
                    # Handle labels (decode if bytes)
                    region_labels = [
                        label.decode('utf-8') if isinstance(label, bytes) else label 
                        for label in current_atlas.labels
                    ]
                    
                    # Create activation dataframe
                    activation_df = pd.DataFrame({
                        'region': region_labels,
                        'activation': regional_values.flatten()
                    })
                    
                    # Add network information (handle both Schaefer and other atlases)
                    activation_df['network'] = activation_df['region'].apply(
                        lambda x: x.split('_')[1] if 'Networks' in x else 'Subcortical'
                    )
                    
                    # Add ROI values if available (for smorgasbord atlas)
                    if hasattr(current_atlas, 'roi_values'):
                        activation_df['roi_value'] = current_atlas.roi_values
                    
                    # Save the activation df
                    parcel_dict[curr_subj][curr_task][curr_contrast] = activation_df
                    print(f"Extracted {len(activation_df)} regions")
                    
                except KeyError as e:
                    print(f"Warning: Data not found - Missing key: {e}")
                    parcel_dict[curr_subj][curr_task][curr_contrast] = None
                    continue
                except Exception as e:
                    print(f"Error processing data: {str(e)}")
                    parcel_dict[curr_subj][curr_task][curr_contrast] = None
                    continue

    # Save to pickle
    output_ending = ""
    if (file_type == "z"):
        output_ending = "_z_scored"
    
    # output_dir = f'processed_data_dfs/{atlas_name}_dfs'
    output_dir = OUTPUT_DIRS[f"{atlas}_fixed"]
    os.makedirs(output_dir, exist_ok=True)
    
    output_file = f'{output_dir}/discovery_parcel_fixedeffects_indiv_updated_{date}{output_ending}.pkl'
    with open(output_file, 'wb') as f:
        pickle.dump(parcel_dict, f)
    
    print(f"\nSaved to: {output_file}")

# %%
save_fixed_subset_of_parcels(1,'1208', atlas="smor", file_type="z")
# Out:
# Loading Smorgasbord atlas...
# Atlas loaded with 429 regions
# Atlas shape: (193, 229, 193)
# doing smor_parcel
# Processing: sub-s03 - nBack - twoBack-oneBack
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - nBack - match-mismatch
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - nBack - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - nBack - response_time
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - flanker - incongruent-congruent
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - flanker - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - directedForgetting - neg-con
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - directedForgetting - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - directedForgetting - response_time
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - goNogo - nogo_success-go
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - goNogo - nogo_success
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - goNogo - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - goNogo - response_time
# Error processing data: 'dict' object has no attribute 'shape'
# Processing: sub-s03 - shapeMatching - DDD
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - shapeMatching - DDS
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - shapeMatching - DNN
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - shapeMatching - DSD
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - shapeMatching - main_vars
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - shapeMatching - SDD
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - shapeMatching - SNN
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - shapeMatching - SSS
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - shapeMatching - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - shapeMatching - response_time
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - stopSignal - go
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - stopSignal - stop_failure-go
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - stopSignal - stop_failure
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - stopSignal - stop_failure-stop_success
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - stopSignal - stop_success-go
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - stopSignal - stop_success
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - stopSignal - stop_success-stop_failure
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - stopSignal - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - stopSignal - response_time
# Error processing data: 'dict' object has no attribute 'shape'
# Processing: sub-s03 - cuedTS - cue_switch_cost
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - cuedTS - task_switch_cost
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - cuedTS - task_switch_cue_switch-task_stay_cue_stay
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - cuedTS - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - cuedTS - response_time
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - spatialTS - cue_switch_cost
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - spatialTS - task_switch_cost
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - spatialTS - task_switch_cue_switch-task_stay_cue_stay
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - spatialTS - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s03 - spatialTS - response_time
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - nBack - twoBack-oneBack
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - nBack - match-mismatch
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - nBack - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - nBack - response_time
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - flanker - incongruent-congruent
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - flanker - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - directedForgetting - neg-con
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - directedForgetting - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - directedForgetting - response_time
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - goNogo - nogo_success-go
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - goNogo - nogo_success
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - goNogo - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - goNogo - response_time
# Error processing data: 'dict' object has no attribute 'shape'
# Processing: sub-s10 - shapeMatching - DDD
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - shapeMatching - DDS
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - shapeMatching - DNN
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - shapeMatching - DSD
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - shapeMatching - main_vars
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - shapeMatching - SDD
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - shapeMatching - SNN
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - shapeMatching - SSS
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - shapeMatching - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - shapeMatching - response_time
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - stopSignal - go
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - stopSignal - stop_failure-go
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - stopSignal - stop_failure
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - stopSignal - stop_failure-stop_success
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - stopSignal - stop_success-go
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - stopSignal - stop_success
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - stopSignal - stop_success-stop_failure
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - stopSignal - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - stopSignal - response_time
# Error processing data: 'dict' object has no attribute 'shape'
# Processing: sub-s10 - cuedTS - cue_switch_cost
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - cuedTS - task_switch_cost
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - cuedTS - task_switch_cue_switch-task_stay_cue_stay
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - cuedTS - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - cuedTS - response_time
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - spatialTS - cue_switch_cost
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - spatialTS - task_switch_cost
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - spatialTS - task_switch_cue_switch-task_stay_cue_stay
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - spatialTS - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s10 - spatialTS - response_time
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - nBack - twoBack-oneBack
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - nBack - match-mismatch
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - nBack - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - nBack - response_time
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - flanker - incongruent-congruent
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - flanker - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - directedForgetting - neg-con
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - directedForgetting - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - directedForgetting - response_time
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - goNogo - nogo_success-go
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - goNogo - nogo_success
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - goNogo - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - goNogo - response_time
# Error processing data: 'dict' object has no attribute 'shape'
# Processing: sub-s19 - shapeMatching - DDD
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - shapeMatching - DDS
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - shapeMatching - DNN
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - shapeMatching - DSD
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - shapeMatching - main_vars
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - shapeMatching - SDD
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - shapeMatching - SNN
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - shapeMatching - SSS
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - shapeMatching - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - shapeMatching - response_time
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - stopSignal - go
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - stopSignal - stop_failure-go
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - stopSignal - stop_failure
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - stopSignal - stop_failure-stop_success
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - stopSignal - stop_success-go
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - stopSignal - stop_success
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - stopSignal - stop_success-stop_failure
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - stopSignal - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - stopSignal - response_time
# Error processing data: 'dict' object has no attribute 'shape'
# Processing: sub-s19 - cuedTS - cue_switch_cost
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - cuedTS - task_switch_cost
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - cuedTS - task_switch_cue_switch-task_stay_cue_stay
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - cuedTS - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - cuedTS - response_time
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - spatialTS - cue_switch_cost
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - spatialTS - task_switch_cost
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - spatialTS - task_switch_cue_switch-task_stay_cue_stay
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - spatialTS - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s19 - spatialTS - response_time
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - nBack - twoBack-oneBack
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - nBack - match-mismatch
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - nBack - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - nBack - response_time
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - flanker - incongruent-congruent
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - flanker - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - directedForgetting - neg-con
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - directedForgetting - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - directedForgetting - response_time
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - goNogo - nogo_success-go
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - goNogo - nogo_success
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - goNogo - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - goNogo - response_time
# Error processing data: 'dict' object has no attribute 'shape'
# Processing: sub-s29 - shapeMatching - DDD
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - shapeMatching - DDS
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - shapeMatching - DNN
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - shapeMatching - DSD
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - shapeMatching - main_vars
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - shapeMatching - SDD
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - shapeMatching - SNN
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - shapeMatching - SSS
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - shapeMatching - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - shapeMatching - response_time
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - stopSignal - go
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - stopSignal - stop_failure-go
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - stopSignal - stop_failure
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - stopSignal - stop_failure-stop_success
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - stopSignal - stop_success-go
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - stopSignal - stop_success
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - stopSignal - stop_success-stop_failure
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - stopSignal - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - stopSignal - response_time
# Error processing data: 'dict' object has no attribute 'shape'
# Processing: sub-s29 - cuedTS - cue_switch_cost
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - cuedTS - task_switch_cost
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - cuedTS - task_switch_cue_switch-task_stay_cue_stay
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - cuedTS - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - cuedTS - response_time
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - spatialTS - cue_switch_cost
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - spatialTS - task_switch_cost
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - spatialTS - task_switch_cue_switch-task_stay_cue_stay
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - spatialTS - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s29 - spatialTS - response_time
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - nBack - twoBack-oneBack
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - nBack - match-mismatch
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - nBack - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - nBack - response_time
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - flanker - incongruent-congruent
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - flanker - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - directedForgetting - neg-con
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - directedForgetting - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - directedForgetting - response_time
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - goNogo - nogo_success-go
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - goNogo - nogo_success
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - goNogo - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - goNogo - response_time
# Error processing data: 'dict' object has no attribute 'shape'
# Processing: sub-s43 - shapeMatching - DDD
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - shapeMatching - DDS
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - shapeMatching - DNN
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - shapeMatching - DSD
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - shapeMatching - main_vars
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - shapeMatching - SDD
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - shapeMatching - SNN
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - shapeMatching - SSS
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - shapeMatching - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - shapeMatching - response_time
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - stopSignal - go
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - stopSignal - stop_failure-go
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - stopSignal - stop_failure
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - stopSignal - stop_failure-stop_success
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - stopSignal - stop_success-go
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - stopSignal - stop_success
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - stopSignal - stop_success-stop_failure
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - stopSignal - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - stopSignal - response_time
# Error processing data: 'dict' object has no attribute 'shape'
# Processing: sub-s43 - cuedTS - cue_switch_cost
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - cuedTS - task_switch_cost
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - cuedTS - task_switch_cue_switch-task_stay_cue_stay
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - cuedTS - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - cuedTS - response_time
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - spatialTS - cue_switch_cost
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - spatialTS - task_switch_cost
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - spatialTS - task_switch_cue_switch-task_stay_cue_stay
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - spatialTS - task-baseline
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
# Processing: sub-s43 - spatialTS - response_time
# fMRI data loaded | Shape: (97, 115, 97)
# Extracted 429 regions
#
# Saved to: processed_data_dfs_updated_dec/smor_parcel_dfs_fixed/discovery_parcel_fixedeffects_indiv_updated_1208_z_scored.pkl

# %%
def average_fixed_subset_of_parcels(run_num, date, atlas='schaefer', file_type = "default"):
    output_ending = ""
    if (file_type == "z"):
        output_ending = "_z_scored"
        
    # Select atlas
    if atlas == 'schaefer':
        atlas_name = 'schaefer400'
        current_atlas = load_schaefer_atlas()
    else:
        atlas_name = 'smor_parcel'
        current_atlas = load_smor_atlas()

    # Load the saved parcellated fixed effects maps for each subject/task/contrast:
    saved_dir = OUTPUT_DIRS[f"{atlas}_fixed"]
    input_file = f'{saved_dir}/discovery_parcel_fixedeffects_indiv_updated_{date}{output_ending}.pkl'
    try:
        with open(input_file, 'rb') as f:
            parcel_dict = pickle.load(f)
    except Exception as e:
        print(f"Error loading the file: {e}")
        return

    # Average these parcellated maps for each task/contrast and save
    averaged_parcel_dict = {}
    for task in TASKS:
        averaged_parcel_dict[task] = {}
        for contrast in CONTRASTS[task]:
            valid_subjects = [subj for subj in SUBJECTS if parcel_dict[subj][task][contrast] is not None]
            if not valid_subjects:
                print(f"No valid data for {task} - {contrast}")
                continue
            
            list_parcel_maps = [parcel_dict[subj][task][contrast]['activation'] for subj in valid_subjects]
            parcel_matrix = np.array(list_parcel_maps)

            # Average across subjects (axis=0)
            avg_parcel_values = np.mean(parcel_matrix, axis=0)
            std_parcel_values = np.std(parcel_matrix, axis=0)
            n_subjects = parcel_matrix.shape[0]
    
            # Create activation dataframe with averaged values
            activation_df = pd.DataFrame({
                'region': parcel_dict[valid_subjects[0]][task][contrast]['region'],
                'activation': avg_parcel_values,
                'activation_std': std_parcel_values,
                'n_subjects': n_subjects
            })
            
            # Add network information (handle both Schaefer and other atlases)
            activation_df['network'] = activation_df['region'].apply(
                lambda x: x.split('_')[1] if 'Networks' in x else 'Subcortical'
            )
            
            # Add ROI values if available (for smorgasbord atlas)
            if hasattr(current_atlas, 'roi_values'):
                activation_df['roi_value'] = current_atlas.roi_values
            
            # Save the activation df
            averaged_parcel_dict[task][contrast] = activation_df
            print(f"  Extracted {len(activation_df)} regions from {n_subjects} subjects for {task}|{contrast} averaging")
    
    # Save to pickle
    output_dir = OUTPUT_DIRS[f"{atlas}_fixed"]
    os.makedirs(output_dir, exist_ok=True)

    output_file = f'{output_dir}/discovery_parcel_fixedeffects_mean_updated_{date}{output_ending}_averaged.pkl'
    with open(output_file, 'wb') as f:
        pickle.dump(averaged_parcel_dict, f)
    
    print(f"\nSaved to: {output_file}")

    print(averaged_parcel_dict)

# %%
average_fixed_subset_of_parcels(1,'1208', atlas="smor", file_type = "z")
# Out:
# Loading Smorgasbord atlas...
# Atlas loaded with 429 regions
# Atlas shape: (193, 229, 193)
#   Extracted 429 regions from 5 subjects for nBack|twoBack-oneBack averaging
#   Extracted 429 regions from 5 subjects for nBack|match-mismatch averaging
#   Extracted 429 regions from 5 subjects for nBack|task-baseline averaging
#   Extracted 429 regions from 5 subjects for nBack|response_time averaging
#   Extracted 429 regions from 5 subjects for flanker|incongruent-congruent averaging
#   Extracted 429 regions from 5 subjects for flanker|task-baseline averaging
#   Extracted 429 regions from 5 subjects for directedForgetting|neg-con averaging
#   Extracted 429 regions from 5 subjects for directedForgetting|task-baseline averaging
#   Extracted 429 regions from 5 subjects for directedForgetting|response_time averaging
#   Extracted 429 regions from 5 subjects for goNogo|nogo_success-go averaging
#   Extracted 429 regions from 5 subjects for goNogo|nogo_success averaging
#   Extracted 429 regions from 5 subjects for goNogo|task-baseline averaging
# No valid data for goNogo - response_time
#   Extracted 429 regions from 5 subjects for shapeMatching|DDD averaging
#   Extracted 429 regions from 5 subjects for shapeMatching|DDS averaging
#   Extracted 429 regions from 5 subjects for shapeMatching|DNN averaging
#   Extracted 429 regions from 5 subjects for shapeMatching|DSD averaging
#   Extracted 429 regions from 5 subjects for shapeMatching|main_vars averaging
#   Extracted 429 regions from 5 subjects for shapeMatching|SDD averaging
#   Extracted 429 regions from 5 subjects for shapeMatching|SNN averaging
#   Extracted 429 regions from 5 subjects for shapeMatching|SSS averaging
#   Extracted 429 regions from 5 subjects for shapeMatching|task-baseline averaging
#   Extracted 429 regions from 5 subjects for shapeMatching|response_time averaging
#   Extracted 429 regions from 5 subjects for stopSignal|go averaging
#   Extracted 429 regions from 5 subjects for stopSignal|stop_failure-go averaging
#   Extracted 429 regions from 5 subjects for stopSignal|stop_failure averaging
#   Extracted 429 regions from 5 subjects for stopSignal|stop_failure-stop_success averaging
#   Extracted 429 regions from 5 subjects for stopSignal|stop_success-go averaging
#   Extracted 429 regions from 5 subjects for stopSignal|stop_success averaging
#   Extracted 429 regions from 5 subjects for stopSignal|stop_success-stop_failure averaging
#   Extracted 429 regions from 5 subjects for stopSignal|task-baseline averaging
# No valid data for stopSignal - response_time
#   Extracted 429 regions from 5 subjects for cuedTS|cue_switch_cost averaging
#   Extracted 429 regions from 5 subjects for cuedTS|task_switch_cost averaging
#   Extracted 429 regions from 5 subjects for cuedTS|task_switch_cue_switch-task_stay_cue_stay averaging
#   Extracted 429 regions from 5 subjects for cuedTS|task-baseline averaging
#   Extracted 429 regions from 5 subjects for cuedTS|response_time averaging
#   Extracted 429 regions from 5 subjects for spatialTS|cue_switch_cost averaging
#   Extracted 429 regions from 5 subjects for spatialTS|task_switch_cost averaging
#   Extracted 429 regions from 5 subjects for spatialTS|task_switch_cue_switch-task_stay_cue_stay averaging
#   Extracted 429 regions from 5 subjects for spatialTS|task-baseline averaging
#   Extracted 429 regions from 5 subjects for spatialTS|response_time averaging
#
# Saved to: processed_data_dfs_updated_dec/smor_parcel_dfs_fixed/discovery_parcel_fixedeffects_mean_updated_1208_z_scored_averaged.pkl.pkl
# {'nBack': {'twoBack-oneBack':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1    0.483017        0.968843           5
# 1              7Networks_LH_Vis_2    0.042042        0.912847           5
# 2              7Networks_LH_Vis_3    0.903095        1.380049           5
# 3              7Networks_LH_Vis_4   -0.050344        1.086142           5
# 4              7Networks_LH_Vis_5    1.333719        0.699991           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left   -0.263725        0.878496           5
# 425     amygdala_basolateral_left   -0.505990        1.023954           5
# 426        amygdala_central_right    0.331430        1.005257           5
# 427  amygdala_corticomedial_right   -0.542803        1.376537           5
# 428    amygdala_basolateral_right   -0.217209        0.775734           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns], 'match-mismatch':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1    0.233258        0.944471           5
# 1              7Networks_LH_Vis_2   -0.350424        0.670907           5
# 2              7Networks_LH_Vis_3    0.546153        1.293373           5
# 3              7Networks_LH_Vis_4    0.004659        1.182947           5
# 4              7Networks_LH_Vis_5    0.119864        2.219698           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left    0.407811        1.261046           5
# 425     amygdala_basolateral_left   -0.264906        1.576434           5
# 426        amygdala_central_right    0.650863        1.362064           5
# 427  amygdala_corticomedial_right    0.618969        1.349960           5
# 428    amygdala_basolateral_right    0.044215        1.108856           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns], 'task-baseline':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1   -1.554923        0.141512           5
# 1              7Networks_LH_Vis_2   -0.553245        1.036063           5
# 2              7Networks_LH_Vis_3   -2.053465        0.994988           5
# 3              7Networks_LH_Vis_4   -0.958600        0.406844           5
# 4              7Networks_LH_Vis_5   -1.551576        1.056996           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left    0.503879        1.099614           5
# 425     amygdala_basolateral_left    0.937507        1.176987           5
# 426        amygdala_central_right    0.927697        1.332271           5
# 427  amygdala_corticomedial_right    0.524716        0.726682           5
# 428    amygdala_basolateral_right    0.952487        0.936223           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns], 'response_time':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1   -1.052204        0.555307           5
# 1              7Networks_LH_Vis_2   -1.704762        0.644804           5
# 2              7Networks_LH_Vis_3   -0.625675        2.358268           5
# 3              7Networks_LH_Vis_4   -2.432169        0.679723           5
# 4              7Networks_LH_Vis_5   -5.470630        0.949659           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left   -1.941207        0.708564           5
# 425     amygdala_basolateral_left   -1.864508        0.949457           5
# 426        amygdala_central_right   -2.399617        0.891233           5
# 427  amygdala_corticomedial_right   -1.472026        0.894791           5
# 428    amygdala_basolateral_right   -1.939522        0.620309           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns]}, 'flanker': {'incongruent-congruent':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1    0.010561        0.251963           5
# 1              7Networks_LH_Vis_2   -0.224424        0.361329           5
# 2              7Networks_LH_Vis_3    0.310864        0.550569           5
# 3              7Networks_LH_Vis_4   -0.239539        0.365137           5
# 4              7Networks_LH_Vis_5   -0.321887        0.602683           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left   -0.099569        0.668225           5
# 425     amygdala_basolateral_left   -0.186094        0.737108           5
# 426        amygdala_central_right   -0.002417        0.852802           5
# 427  amygdala_corticomedial_right   -0.015110        0.786598           5
# 428    amygdala_basolateral_right   -0.164203        0.983422           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns], 'task-baseline':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1   -2.165812        1.291835           5
# 1              7Networks_LH_Vis_2   -1.011595        1.437900           5
# 2              7Networks_LH_Vis_3   -2.763663        1.169019           5
# 3              7Networks_LH_Vis_4   -1.734374        1.255291           5
# 4              7Networks_LH_Vis_5   -3.081710        1.705031           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left   -0.277052        1.402402           5
# 425     amygdala_basolateral_left    0.215862        1.672686           5
# 426        amygdala_central_right   -0.048032        1.748110           5
# 427  amygdala_corticomedial_right   -0.557983        1.054240           5
# 428    amygdala_basolateral_right    0.065398        1.398858           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns]}, 'directedForgetting': {'neg-con':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1    0.345902        0.625027           5
# 1              7Networks_LH_Vis_2   -0.060476        0.634933           5
# 2              7Networks_LH_Vis_3    0.164734        0.917213           5
# 3              7Networks_LH_Vis_4   -0.374458        0.793295           5
# 4              7Networks_LH_Vis_5   -0.171149        0.594969           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left    0.071551        0.557522           5
# 425     amygdala_basolateral_left   -0.234695        0.554550           5
# 426        amygdala_central_right    0.213517        0.580379           5
# 427  amygdala_corticomedial_right    0.143970        0.666673           5
# 428    amygdala_basolateral_right    0.097332        0.822740           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns], 'task-baseline':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1    0.690331        2.190178           5
# 1              7Networks_LH_Vis_2    0.228814        0.740068           5
# 2              7Networks_LH_Vis_3    2.020769        2.989201           5
# 3              7Networks_LH_Vis_4    3.563438        1.958039           5
# 4              7Networks_LH_Vis_5    3.728695        2.207932           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left    0.141648        0.373762           5
# 425     amygdala_basolateral_left   -0.044165        1.007542           5
# 426        amygdala_central_right    0.495352        2.266717           5
# 427  amygdala_corticomedial_right    0.192123        0.994207           5
# 428    amygdala_basolateral_right    0.271329        1.589936           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns], 'response_time':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1   -1.129603        0.576165           5
# 1              7Networks_LH_Vis_2   -0.838928        0.555285           5
# 2              7Networks_LH_Vis_3   -2.615038        1.650351           5
# 3              7Networks_LH_Vis_4   -2.402544        1.583182           5
# 4              7Networks_LH_Vis_5   -4.058941        1.459531           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left    0.151458        0.496251           5
# 425     amygdala_basolateral_left   -0.125727        0.450466           5
# 426        amygdala_central_right   -0.693339        1.328825           5
# 427  amygdala_corticomedial_right   -0.036091        0.457742           5
# 428    amygdala_basolateral_right   -0.389308        0.813814           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns]}, 'goNogo': {'nogo_success-go':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1    1.323259        0.853542           5
# 1              7Networks_LH_Vis_2   -0.367611        0.865270           5
# 2              7Networks_LH_Vis_3    1.488449        1.031752           5
# 3              7Networks_LH_Vis_4    0.555749        0.602984           5
# 4              7Networks_LH_Vis_5    0.830151        0.790961           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left   -0.582776        0.992233           5
# 425     amygdala_basolateral_left   -0.565742        1.246757           5
# 426        amygdala_central_right   -1.000701        1.048556           5
# 427  amygdala_corticomedial_right   -0.393330        0.840374           5
# 428    amygdala_basolateral_right   -0.855210        1.141578           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns], 'nogo_success':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1   -0.628720        0.499666           5
# 1              7Networks_LH_Vis_2   -1.248450        1.262190           5
# 2              7Networks_LH_Vis_3   -0.335804        2.890132           5
# 3              7Networks_LH_Vis_4   -1.276246        1.373827           5
# 4              7Networks_LH_Vis_5   -1.760031        2.167308           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left   -0.763402        1.930737           5
# 425     amygdala_basolateral_left   -0.488620        2.274762           5
# 426        amygdala_central_right   -1.320674        1.877384           5
# 427  amygdala_corticomedial_right   -0.763348        1.381794           5
# 428    amygdala_basolateral_right   -0.724672        1.771355           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns], 'task-baseline':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1   -3.008089        2.073529           5
# 1              7Networks_LH_Vis_2   -1.462982        1.434984           5
# 2              7Networks_LH_Vis_3   -2.720226        4.765942           5
# 3              7Networks_LH_Vis_4   -2.875980        2.398928           5
# 4              7Networks_LH_Vis_5   -3.966915        3.269581           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left   -0.350011        1.702474           5
# 425     amygdala_basolateral_left    0.073083        2.159342           5
# 426        amygdala_central_right   -0.603926        1.938036           5
# 427  amygdala_corticomedial_right   -0.622840        1.443313           5
# 428    amygdala_basolateral_right    0.128957        1.668862           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns]}, 'shapeMatching': {'DDD':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1   -1.603350        1.209799           5
# 1              7Networks_LH_Vis_2   -0.745388        0.894974           5
# 2              7Networks_LH_Vis_3   -1.033445        1.741035           5
# 3              7Networks_LH_Vis_4   -1.761761        1.513033           5
# 4              7Networks_LH_Vis_5   -1.059522        1.796329           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left    0.516840        1.371541           5
# 425     amygdala_basolateral_left    1.232610        1.575984           5
# 426        amygdala_central_right    0.681331        1.014765           5
# 427  amygdala_corticomedial_right    0.602289        1.376687           5
# 428    amygdala_basolateral_right    0.967075        1.084231           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns], 'DDS':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1   -1.165898        1.297370           5
# 1              7Networks_LH_Vis_2   -0.727434        0.865659           5
# 2              7Networks_LH_Vis_3   -0.748988        2.070096           5
# 3              7Networks_LH_Vis_4   -1.585654        1.453854           5
# 4              7Networks_LH_Vis_5   -0.987165        1.880925           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left    0.357540        1.608075           5
# 425     amygdala_basolateral_left    0.959287        1.518880           5
# 426        amygdala_central_right    0.495485        1.024071           5
# 427  amygdala_corticomedial_right    0.513693        1.476575           5
# 428    amygdala_basolateral_right    0.715593        1.201312           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns], 'DNN':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1   -1.921523        0.887315           5
# 1              7Networks_LH_Vis_2   -0.651707        0.950954           5
# 2              7Networks_LH_Vis_3   -1.901315        1.724468           5
# 3              7Networks_LH_Vis_4   -2.064631        1.062724           5
# 4              7Networks_LH_Vis_5   -1.903091        1.228598           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left    0.475037        1.707471           5
# 425     amygdala_basolateral_left    1.199652        1.787139           5
# 426        amygdala_central_right    0.855056        1.488823           5
# 427  amygdala_corticomedial_right    0.533984        1.764689           5
# 428    amygdala_basolateral_right    1.017358        1.537441           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns], 'DSD':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1   -1.605353        1.217843           5
# 1              7Networks_LH_Vis_2   -0.611573        0.931802           5
# 2              7Networks_LH_Vis_3   -1.311497        1.973146           5
# 3              7Networks_LH_Vis_4   -1.666260        1.569246           5
# 4              7Networks_LH_Vis_5   -1.392891        1.719469           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left    0.160199        1.266658           5
# 425     amygdala_basolateral_left    0.964078        1.293086           5
# 426        amygdala_central_right    0.609623        0.741467           5
# 427  amygdala_corticomedial_right    0.450043        1.125724           5
# 428    amygdala_basolateral_right    0.833052        0.881950           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns], 'main_vars':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1    0.764785        1.439250           5
# 1              7Networks_LH_Vis_2   -0.273516        0.877682           5
# 2              7Networks_LH_Vis_3    2.118531        1.217808           5
# 3              7Networks_LH_Vis_4    0.506597        1.446888           5
# 4              7Networks_LH_Vis_5    1.880807        1.946993           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left    0.032655        0.446180           5
# 425     amygdala_basolateral_left    0.288127        0.440405           5
# 426        amygdala_central_right   -0.290637        0.576893           5
# 427  amygdala_corticomedial_right    0.543153        0.357517           5
# 428    amygdala_basolateral_right   -0.030572        0.422819           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns], 'SDD':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1   -1.651020        1.280862           5
# 1              7Networks_LH_Vis_2   -0.697033        0.844292           5
# 2              7Networks_LH_Vis_3   -1.293605        1.917317           5
# 3              7Networks_LH_Vis_4   -1.768001        1.441489           5
# 4              7Networks_LH_Vis_5   -1.372398        1.641450           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left    0.616980        1.452905           5
# 425     amygdala_basolateral_left    1.203953        1.770660           5
# 426        amygdala_central_right    0.788918        1.175845           5
# 427  amygdala_corticomedial_right    0.647361        1.562541           5
# 428    amygdala_basolateral_right    0.926848        1.381237           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns], 'SNN':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1   -1.820184        1.237604           5
# 1              7Networks_LH_Vis_2   -0.748344        1.051020           5
# 2              7Networks_LH_Vis_3   -1.764048        1.917724           5
# 3              7Networks_LH_Vis_4   -1.979687        1.407760           5
# 4              7Networks_LH_Vis_5   -1.847270        1.434451           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left    0.577749        1.383489           5
# 425     amygdala_basolateral_left    1.060322        1.600109           5
# 426        amygdala_central_right    0.763506        1.121434           5
# 427  amygdala_corticomedial_right    0.356057        1.402407           5
# 428    amygdala_basolateral_right    0.876793        1.118587           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns], 'SSS':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1   -1.733494        0.996935           5
# 1              7Networks_LH_Vis_2   -0.763316        0.922016           5
# 2              7Networks_LH_Vis_3   -1.196165        1.636282           5
# 3              7Networks_LH_Vis_4   -1.827501        1.223831           5
# 4              7Networks_LH_Vis_5   -1.267224        1.427941           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left    0.558906        1.349966           5
# 425     amygdala_basolateral_left    1.056380        1.415541           5
# 426        amygdala_central_right    0.573209        0.902714           5
# 427  amygdala_corticomedial_right    0.473998        1.444266           5
# 428    amygdala_basolateral_right    0.740526        1.093802           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns], 'task-baseline':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1   -1.733118        1.196551           5
# 1              7Networks_LH_Vis_2   -0.753312        0.954664           5
# 2              7Networks_LH_Vis_3   -1.385194        1.931705           5
# 3              7Networks_LH_Vis_4   -1.902846        1.426671           5
# 4              7Networks_LH_Vis_5   -1.468233        1.647055           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left    0.496078        1.528150           5
# 425     amygdala_basolateral_left    1.167303        1.642867           5
# 426        amygdala_central_right    0.721281        1.113660           5
# 427  amygdala_corticomedial_right    0.545125        1.534264           5
# 428    amygdala_basolateral_right    0.920207        1.247747           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns], 'response_time':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1    2.384016        0.741450           5
# 1              7Networks_LH_Vis_2    0.662928        1.045795           5
# 2              7Networks_LH_Vis_3    3.304953        0.927989           5
# 3              7Networks_LH_Vis_4    2.176635        0.795826           5
# 4              7Networks_LH_Vis_5    2.733510        0.479489           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left   -0.610423        1.436364           5
# 425     amygdala_basolateral_left   -1.065707        1.405014           5
# 426        amygdala_central_right   -0.652679        1.020501           5
# 427  amygdala_corticomedial_right   -0.508061        1.159258           5
# 428    amygdala_basolateral_right   -0.822302        1.057789           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns]}, 'stopSignal': {'go':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1   -3.637466        1.167798           5
# 1              7Networks_LH_Vis_2   -2.675237        1.376780           5
# 2              7Networks_LH_Vis_3   -3.414366        3.829832           5
# 3              7Networks_LH_Vis_4   -4.348985        1.449238           5
# 4              7Networks_LH_Vis_5   -7.133823        1.444853           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left   -1.179632        1.377147           5
# 425     amygdala_basolateral_left   -0.316512        1.468638           5
# 426        amygdala_central_right   -0.391711        1.735149           5
# 427  amygdala_corticomedial_right   -0.456575        0.424476           5
# 428    amygdala_basolateral_right   -0.026904        1.260970           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns], 'stop_failure-go':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1    3.180640        1.010851           5
# 1              7Networks_LH_Vis_2   -0.491014        0.954147           5
# 2              7Networks_LH_Vis_3    5.293203        2.058391           5
# 3              7Networks_LH_Vis_4    1.275413        0.877575           5
# 4              7Networks_LH_Vis_5    3.198547        1.497499           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left   -1.962779        0.909900           5
# 425     amygdala_basolateral_left   -2.127433        0.774654           5
# 426        amygdala_central_right   -2.453121        1.040825           5
# 427  amygdala_corticomedial_right   -1.803682        0.586521           5
# 428    amygdala_basolateral_right   -2.447092        0.887476           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns], 'stop_failure':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1    1.474456        1.169918           5
# 1              7Networks_LH_Vis_2   -2.501816        1.037900           5
# 2              7Networks_LH_Vis_3    3.782396        2.231016           5
# 3              7Networks_LH_Vis_4   -1.106587        1.649570           5
# 4              7Networks_LH_Vis_5   -0.848498        2.024090           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left   -3.375815        1.614907           5
# 425     amygdala_basolateral_left   -2.889820        1.454129           5
# 426        amygdala_central_right   -3.447110        2.239448           5
# 427  amygdala_corticomedial_right   -2.767630        0.654325           5
# 428    amygdala_basolateral_right   -3.279358        1.399325           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns], 'stop_failure-stop_success':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1    0.300819        0.641116           5
# 1              7Networks_LH_Vis_2   -1.103328        0.458473           5
# 2              7Networks_LH_Vis_3    0.604544        0.980890           5
# 3              7Networks_LH_Vis_4   -0.262684        0.435024           5
# 4              7Networks_LH_Vis_5   -0.480884        0.667405           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left   -1.395400        0.795717           5
# 425     amygdala_basolateral_left   -1.027316        0.897517           5
# 426        amygdala_central_right   -1.361235        1.169931           5
# 427  amygdala_corticomedial_right   -1.241483        0.102891           5
# 428    amygdala_basolateral_right   -1.388560        0.589707           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns], 'stop_success-go':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1    3.037693        0.325387           5
# 1              7Networks_LH_Vis_2    0.962092        0.498413           5
# 2              7Networks_LH_Vis_3    4.836926        1.446674           5
# 3              7Networks_LH_Vis_4    1.726864        0.474982           5
# 4              7Networks_LH_Vis_5    4.028647        1.984942           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left   -0.242634        1.052796           5
# 425     amygdala_basolateral_left   -0.936366        1.336468           5
# 426        amygdala_central_right   -0.805972        1.446531           5
# 427  amygdala_corticomedial_right   -0.283989        0.664343           5
# 428    amygdala_basolateral_right   -0.777118        0.966274           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns], 'stop_success':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1    0.787653        0.754550           5
# 1              7Networks_LH_Vis_2    0.190206        0.609047           5
# 2              7Networks_LH_Vis_3    2.431275        1.945519           5
# 3              7Networks_LH_Vis_4   -0.459762        1.012278           5
# 4              7Networks_LH_Vis_5    0.344201        2.725196           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left    0.031091        0.849509           5
# 425     amygdala_basolateral_left   -0.436025        1.182479           5
# 426        amygdala_central_right   -0.134965        1.619441           5
# 427  amygdala_corticomedial_right    0.259648        0.755223           5
# 428    amygdala_basolateral_right    0.102644        1.108340           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns], 'stop_success-stop_failure':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1   -0.300819        0.641116           5
# 1              7Networks_LH_Vis_2    1.103328        0.458473           5
# 2              7Networks_LH_Vis_3   -0.604544        0.980890           5
# 3              7Networks_LH_Vis_4    0.262684        0.435024           5
# 4              7Networks_LH_Vis_5    0.480884        0.667405           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left    1.395400        0.795717           5
# 425     amygdala_basolateral_left    1.027316        0.897517           5
# 426        amygdala_central_right    1.361235        1.169931           5
# 427  amygdala_corticomedial_right    1.241483        0.102891           5
# 428    amygdala_basolateral_right    1.388560        0.589707           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns], 'task-baseline':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1   -1.759710        1.088756           5
# 1              7Networks_LH_Vis_2   -2.635755        1.219932           5
# 2              7Networks_LH_Vis_3   -0.287055        3.579891           5
# 3              7Networks_LH_Vis_4   -3.541786        1.858988           5
# 4              7Networks_LH_Vis_5   -5.061137        2.371045           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left   -1.948994        1.305607           5
# 425     amygdala_basolateral_left   -1.336346        1.268332           5
# 426        amygdala_central_right   -1.480490        1.924276           5
# 427  amygdala_corticomedial_right   -1.170649        0.680263           5
# 428    amygdala_basolateral_right   -1.094249        1.405442           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns]}, 'cuedTS': {'cue_switch_cost':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1    0.152610        0.474631           5
# 1              7Networks_LH_Vis_2   -0.322965        0.638846           5
# 2              7Networks_LH_Vis_3    0.057556        0.477833           5
# 3              7Networks_LH_Vis_4   -0.432217        0.297930           5
# 4              7Networks_LH_Vis_5   -0.402545        0.293822           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left    0.214117        1.179165           5
# 425     amygdala_basolateral_left   -0.571055        0.545310           5
# 426        amygdala_central_right   -0.461984        0.956121           5
# 427  amygdala_corticomedial_right    0.093730        0.383649           5
# 428    amygdala_basolateral_right   -0.430204        0.781142           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns], 'task_switch_cost':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1   -0.130296        0.526863           5
# 1              7Networks_LH_Vis_2   -0.127978        0.304155           5
# 2              7Networks_LH_Vis_3   -0.261114        1.035201           5
# 3              7Networks_LH_Vis_4    0.133651        0.714272           5
# 4              7Networks_LH_Vis_5    0.081517        0.953903           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left   -0.270808        0.804462           5
# 425     amygdala_basolateral_left    0.085163        0.661523           5
# 426        amygdala_central_right   -0.115193        0.897703           5
# 427  amygdala_corticomedial_right   -0.160407        0.995794           5
# 428    amygdala_basolateral_right    0.086467        0.579619           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns], 'task_switch_cue_switch-task_stay_cue_stay':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1    0.034775        0.814820           5
# 1              7Networks_LH_Vis_2   -0.481233        0.679612           5
# 2              7Networks_LH_Vis_3   -0.198266        0.862624           5
# 3              7Networks_LH_Vis_4   -0.324512        0.640032           5
# 4              7Networks_LH_Vis_5   -0.341487        0.921008           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left   -0.044813        0.549945           5
# 425     amygdala_basolateral_left   -0.528901        0.946025           5
# 426        amygdala_central_right   -0.613016        1.035285           5
# 427  amygdala_corticomedial_right   -0.054641        0.871775           5
# 428    amygdala_basolateral_right   -0.377655        1.015940           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns], 'task-baseline':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1   -1.217578        0.513700           5
# 1              7Networks_LH_Vis_2   -0.954051        1.376332           5
# 2              7Networks_LH_Vis_3   -1.307492        1.302674           5
# 3              7Networks_LH_Vis_4   -1.842926        1.112275           5
# 4              7Networks_LH_Vis_5   -2.464088        0.982296           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left    0.182926        1.178673           5
# 425     amygdala_basolateral_left    0.605128        1.578122           5
# 426        amygdala_central_right    0.056581        1.989774           5
# 427  amygdala_corticomedial_right   -0.004617        1.261167           5
# 428    amygdala_basolateral_right    0.096271        1.629329           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns], 'response_time':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1    0.692379        0.992208           5
# 1              7Networks_LH_Vis_2   -0.757640        1.332580           5
# 2              7Networks_LH_Vis_3    1.487687        1.387025           5
# 3              7Networks_LH_Vis_4   -0.225768        1.679513           5
# 4              7Networks_LH_Vis_5    0.070363        1.851328           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left   -0.838116        0.617184           5
# 425     amygdala_basolateral_left   -1.217210        1.039753           5
# 426        amygdala_central_right   -1.252227        0.955567           5
# 427  amygdala_corticomedial_right   -0.783809        0.584801           5
# 428    amygdala_basolateral_right   -1.137084        0.823769           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns]}, 'spatialTS': {'cue_switch_cost':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1    0.179145        0.404789           5
# 1              7Networks_LH_Vis_2   -0.085901        0.257705           5
# 2              7Networks_LH_Vis_3    0.178312        0.501269           5
# 3              7Networks_LH_Vis_4   -0.062000        0.782848           5
# 4              7Networks_LH_Vis_5    0.206540        0.877496           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left    0.040817        0.711940           5
# 425     amygdala_basolateral_left   -0.031626        0.824994           5
# 426        amygdala_central_right   -0.123044        0.807571           5
# 427  amygdala_corticomedial_right   -0.123109        0.450428           5
# 428    amygdala_basolateral_right   -0.102503        0.978301           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns], 'task_switch_cost':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1   -0.114820        0.341575           5
# 1              7Networks_LH_Vis_2   -0.005074        0.285309           5
# 2              7Networks_LH_Vis_3   -0.113265        0.718385           5
# 3              7Networks_LH_Vis_4    0.106864        0.505736           5
# 4              7Networks_LH_Vis_5    0.239873        0.981498           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left    0.011906        0.588403           5
# 425     amygdala_basolateral_left   -0.261017        0.434509           5
# 426        amygdala_central_right   -0.159503        0.472086           5
# 427  amygdala_corticomedial_right   -0.189502        0.532681           5
# 428    amygdala_basolateral_right   -0.187794        0.425593           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns], 'task_switch_cue_switch-task_stay_cue_stay':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1    0.050764        0.607585           5
# 1              7Networks_LH_Vis_2   -0.097263        0.385100           5
# 2              7Networks_LH_Vis_3    0.048186        1.119070           5
# 3              7Networks_LH_Vis_4    0.011239        1.046211           5
# 4              7Networks_LH_Vis_5    0.403112        1.293497           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left    0.051111        0.810245           5
# 425     amygdala_basolateral_left   -0.273500        1.023123           5
# 426        amygdala_central_right   -0.275503        0.552809           5
# 427  amygdala_corticomedial_right   -0.312326        0.849777           5
# 428    amygdala_basolateral_right   -0.281442        0.684923           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns], 'task-baseline':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1   -2.298352        1.495661           5
# 1              7Networks_LH_Vis_2   -1.305424        0.774550           5
# 2              7Networks_LH_Vis_3   -1.837322        2.197335           5
# 3              7Networks_LH_Vis_4   -0.965340        1.030593           5
# 4              7Networks_LH_Vis_5   -2.042181        1.330043           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left   -0.102403        1.094342           5
# 425     amygdala_basolateral_left    0.146778        1.323668           5
# 426        amygdala_central_right   -0.612283        0.222592           5
# 427  amygdala_corticomedial_right    0.022767        0.725278           5
# 428    amygdala_basolateral_right    0.071081        0.204548           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns], 'response_time':                            region  activation  activation_std  n_subjects  \
# 0              7Networks_LH_Vis_1    0.825096        0.898678           5
# 1              7Networks_LH_Vis_2   -0.318523        0.623641           5
# 2              7Networks_LH_Vis_3    1.219983        1.120500           5
# 3              7Networks_LH_Vis_4   -0.163664        0.980814           5
# 4              7Networks_LH_Vis_5   -0.152354        1.101368           5
# ..                            ...         ...             ...         ...
# 424   amygdala_corticomedial_left   -0.737521        1.286481           5
# 425     amygdala_basolateral_left   -0.729168        1.087802           5
# 426        amygdala_central_right   -0.849699        1.439044           5
# 427  amygdala_corticomedial_right   -0.484218        0.790878           5
# 428    amygdala_basolateral_right   -0.856920        0.810571           5
#
#          network  roi_value
# 0             LH        1.0
# 1             LH        2.0
# 2             LH        3.0
# 3             LH        4.0
# 4             LH        5.0
# ..           ...        ...
# 424  Subcortical      602.0
# 425  Subcortical      603.0
# 426  Subcortical      604.0
# 427  Subcortical      605.0
# 428  Subcortical      606.0
#
# [429 rows x 6 columns]}}

# %%
print(averaged_parcel_dict)
